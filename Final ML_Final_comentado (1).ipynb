# %% [markdown]
# <div class="alert alert-block alert-info">
# <center> <h1> Machine Learning - PROJECT </h1> </center> <br>
# <center> <h2> Group 26 </h2> </center> <br>
#     <center> <h3> 2024/2025 </h3> </center>

# %% [markdown]
# Student Name - Pedro Santos <br>
# Student id - 20240295 <br>
# Contact e-mail - 20240295@novaims.unl.pt <br>
#
# Student Name - Diogo Correia   <br>
# Student id - 20211586  <br>
# Contact e-mail - 20211586@novaims.unl.pt <br>
#
# Student Name - Oumaima Ben Hfaiedh  <br>
# Student id - 20240699 <br>
# Contact e-mail - 20240699@novaims.unl.pt  <br>
#
# Student Name -   <br>
# Student id -  <br>
# Contact e-mail -  <br>
#
# Student Name -   <br>
# Student id -  <br>
# Contact e-mail -  <br>

# %% [markdown]
# # <a id = "Index"></a>
#
# # Table of Contents

# %% [markdown]
# **0. [Context and Metadata](#context)**
#
# **1. [Importing and Loading of Dataset](#importlibraries)**
#    - [1.1 Importing Libraries](#importlibraries)
#    - [1.2 Loading and Reading Data](#loadingdata)
#    - [1.3 Brief Priliminary Analysis](#briefanalysis)
#    - [1.4 Notes](#notes)
#
#
# **2 [Exploratory Data Analysis](#eda)**
#    - [2.1 Numerical Visulization](#numerical)
#       - [2.1.1 Age at Injury](#age)
#       - [2.1.2 Average Weekly Wage](#wage)
#       - [2.1.3 Birth Year](#birth)
#       - [2.1.4 IME-4 Count](#IME)
#       - [2.1.5 Industry Count](#industrycount)
#       - [2.1.6 WCIO Cause of Injury Code](#causecode)
#       - [2.1.7 WCIO Nature of Injury Code](#naturecode)
#       - [2.1.8 WCIO Part of body Code](#bodycode)
#       - [2.1.9 Number of Dependents](#dependents)
#    - [2.2 Dates Visulization](#dates)
#      - [2.2.1 Accident Date](#accidentdate)
#      - [2.2.2 Assembly Date](#assemblydate)
#      - [2.2.3 C-2 Date](#c2date)
#      - [2.2.4 C-3 Date](#c3date)
#      - [2.2.5 First Hearing Date](#firsthearingdate)
#    - [2.3 Categorical Visualization](#categorical)
#      - [2.3.1 Attorney/Representative](#attorney)
#      - [2.3.2 Carrier Name](#carrier)
#      - [2.3.3 Alternative Dispute Resolution](#resolution)
#      - [2.3.4 Carrier Type](#carriertype)
#      - [2.3.5 Claim Injury Type](#claimtype)
#      - [2.3.6 County of Injury](#county)
#      - [2.3.7 COVID-19 Indicator](#covid)
#      - [2.3.8 District Name](#district)
#      - [2.3.9 Gender](#gender)
#      - [2.3.10 Agreement Reached](#agreement)
#
# **3 [Data Preprocessing](#preprocessing)**
#    - [3.1 Splitting Training Dataset and Fixing Incoherneces](#incoherences)
#    - [3.2 Adressing Missing Values](#missing)
#    - [3.3 Feature Engineering](#feature)
#    - [3.3 KNN Imputation and Scaling Data](#scaling)
#    - [3.4 Categorical Data Encoding](#encoding)
#
# **4 [Feature Selection](#featureselection)**
#    - [4.1 Filter Methods](#filter)
#      - [4.4.1 Univariate Variables ](#univariate)
#      - [4.4.2 Correlation Indices](#correlation)
#    - [4.2 Wrapper Methods](#wrapper)
#      - [4.2.1 RFE](#rfe)
#    - [4.3 Embedded Methods](#embedded)
#      - [4.2.1 LASSO](#lasso)
#
# **5 [Model Assessment](#model)**

# %% [markdown]
#  <a class="anchor" id="context">
#
# # 0. Context and Meta Data
#
# </a>

# %% [markdown]
# #### Predictors
# `Accident Date` - Injury date of the claim.<br>
# `Age at Injury` -  Age of injured worker when the injury occurred. <br>
# `Alternative Dispute Resolution` - Adjudication processes external to the Board. <br>
# `Assembly Date` - The date the claim was first assembled. <br>
# `Attorney/Representative` - Is the claim being represented by an Attorney? <br>
# `Average Weekly Wage` - The wage used to calculate workers’ compensation,
# disability, or an Paid Leave wage replacement benefits <br>
# `Birth Year` - The reported year of birth of the injured worker. <br>
# `C-2 Date` - Date of receipt of the Employer's Report of Work-Related
# Injury/Illness or equivalent (formerly Form C-2) <<br>
# `C-3 Dtae`  Date Form C-3 (Employee Claim Form) was received.- <br>
# `Carrier Name` -Name of primary insurance provider responsible for providing workers compensation coverage to the injured workers employe. <br> `Carrier Type` - Type of primary insurance provider responsible for providing workers compensation coverage.<br>
# `Claim Identifier` - Unique identifier for each claim, assigned by WCB <br>
# `County of Injury` - Name of the New York County where the injury occurred  <br>
# `COVID-19 Indicator`- Indication that the claim may be associated with COVID-19 <br>
# `District Name` - Name of the WCB district office that oversees claims for that region or area of the state.<br>
# `First Hearing Date` - Date the first hearing was held on a claim at a WCB hearing location. A blank date means the claim has not yet had a hearing held.<br>
# `Gender` - The reported gender of the injured worker <br>
# `IME-4 Count`- Number of IME-4 forms received per claim. The IME-4 form is
# the “Independent Examiner's Report of Independent Medical
# Examination” form. <br>
# `Industry Code`- The code of the industry where the worker works<br>
# `Industry Code Description`-  The description realted to the industry where the worker works<br>
# `Medical Fee Region`- Approximate region where the injured worker would receive medical service <br>
# `OIICS Nature of Injury Description`- OIICS Nature of Injury Description <br>
# `WCIO Cause of Injury Code`- The code of the cause of Injury <br>
# `WCIO Cause of Injury Description`- The description related to the code of the cause of injury<br>
# `WCIO Nature of Injury Code`- The code of the nature of injury <br>
# `WCIO Nature of Injury Description`- The description related to the code of the nature of injury<br>
# `WCIO Part Of Body Code`- The code of the workers body part that was injured <br>
# `WCIO Part Of Body Description`- The descrition related to the code of the workers body part that was injured <br>
# `Zip Code`- The reported ZIP code of the injured worker’s home address.<br>
# `Agreement Reached` - Binary variable: Yes if there is an agreement without the involvement of the WCB -> unknown at the start of a claim <br>
# `Number of Dependents`- Number of dependers on the workers (family members) <br>
# `WCB Decision`-Multiclass variable: Decision of the WCB relative to the claim:
# “Accident” means that claim refers to workplace accident,
# “Occupational Disease” means illness from the workplace. ->
# requires WCB deliberation so it is unknown at start of claim <br>
# #### Target
# `Claim Injury Type`- Main target variable: Deliberation of the WCB relative to
# benefits awarded to the claim. Numbering indicates severity<br>
# <br>

# %% [markdown]
#  <a class="anchor" id="importlibraries">
#
# # 1. Importing and Loading of Dataset
#
# </a>

# %% [markdown]
# <a class="anchor" id="importlibraries">
#
# ## 1.1. Importing Libraries
#
# </a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# data partition
from sklearn.model_selection import train_test_split

# Imputing
from sklearn.impute import KNNImputer

#filter methods
# spearman 
# chi-square
import scipy.stats as stats
from scipy.stats import chi2_contingency

#wrapper methods
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.feature_selection import RFE
from sklearn.feature_selection import RFECV
from sklearn.preprocessing import RobustScaler


# embedded methods
from sklearn.linear_model import LassoCV

# Encoding
from sklearn.preprocessing import OrdinalEncoder, LabelEncoder, OneHotEncoder

# Modelling and report
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, f1_score, make_scorer, confusion_matrix, accuracy_score, precision_score, recall_score, roc_auc_score, roc_curve, auc
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import StackingClassifier
from sklearn.neighbors import KNeighborsClassifier
from catboost import CatBoostClassifier

from sklearn.model_selection import GridSearchCV, KFold, cross_val_score, RandomizedSearchCV, StratifiedKFold

import warnings
warnings.filterwarnings('ignore')

#from ydata_profiling import ProfileReport

# %% [markdown]
# <a class="anchor" id="loadingdata">
#
# ## 1.2. Loading and Reading Data
#
# </a>

# %% [markdown]
# We start off by importing our dataset using read_csv from pandas.

# %%
# Importing training and testing dataset
train = pd.read_csv("train_data.csv") 
test = pd.read_csv("test_data.csv")

# %% [markdown]
# <span style="font-family:Calibri; font-size:16px;">
# We start by checking the size of <span style="color:green; font-weight:bold">Train </span> and <span style="color:green; font-weight:bold">Test </span> datasets
# </span>

# %%
print(train.shape)
print(test.shape)
# Out:
# (593471, 33)
# (387975, 30)

# %% [markdown]
# <span style="font-family:Calibri; font-size:16px;">
# Then we checked the first 5 rows of each dataset:
# </span>

# %%
train.head()
# Out:
#   Accident Date  Age at Injury Alternative Dispute Resolution Assembly Date  \
# 0    2019-12-30           31.0                              N    2020-01-01
# 1    2019-08-30           46.0                              N    2020-01-01
# 2    2019-12-06           40.0                              N    2020-01-01
# 3           NaN            NaN                            NaN    2020-01-01
# 4    2019-12-30           61.0                              N    2020-01-01
#
#   Attorney/Representative  Average Weekly Wage  Birth Year    C-2 Date  \
# 0                       N                 0.00      1988.0  2019-12-31
# 1                       Y              1745.93      1973.0  2020-01-01
# 2                       N              1434.80      1979.0  2020-01-01
# 3                     NaN                  NaN         NaN         NaN
# 4                       N                  NaN      1958.0  2019-12-31
#
#      C-3 Date                  Carrier Name  ... WCIO Cause of Injury Code  \
# 0         NaN    NEW HAMPSHIRE INSURANCE CO  ...                      27.0
# 1  2020-01-14  ZURICH AMERICAN INSURANCE CO  ...                      97.0
# 2         NaN     INDEMNITY INSURANCE CO OF  ...                      79.0
# 3         NaN                           NaN  ...                       NaN
# 4         NaN          STATE INSURANCE FUND  ...                      16.0
#
#    WCIO Cause of Injury Description WCIO Nature of Injury Code  \
# 0      FROM LIQUID OR GREASE SPILLS                       10.0
# 1                 REPETITIVE MOTION                       49.0
# 2    OBJECT BEING LIFTED OR HANDLED                        7.0
# 3                               NaN                        NaN
# 4   HAND TOOL, UTENSIL; NOT POWERED                       43.0
#
#   WCIO Nature of Injury Description WCIO Part Of Body Code  \
# 0                         CONTUSION                   62.0
# 1                    SPRAIN OR TEAR                   38.0
# 2                        CONCUSSION                   10.0
# 3                               NaN                    NaN
# 4                          PUNCTURE                   36.0
#
#   WCIO Part Of Body Description Zip Code Agreement Reached      WCB Decision  \
# 0                      BUTTOCKS    13662               0.0  Not Work Related
# 1                   SHOULDER(S)    14569               1.0  Not Work Related
# 2          MULTIPLE HEAD INJURY    12589               0.0  Not Work Related
# 3                           NaN      NaN               NaN               NaN
# 4                     FINGER(S)    12603               0.0  Not Work Related
#
#    Number of Dependents
# 0                   1.0
# 1                   4.0
# 2                   6.0
# 3                   NaN
# 4                   1.0
#
# [5 rows x 33 columns]

# %%
test.head()
# Out:
#   Accident Date  Age at Injury Alternative Dispute Resolution Assembly Date  \
# 0    2022-12-24             19                              N    2023-01-02
# 1    2022-11-20             19                              N    2023-01-02
# 2    2022-12-26             59                              N    2023-01-02
# 3    2022-12-28             55                              N    2023-01-02
# 4    2022-12-20             25                              N    2023-01-02
#
#   Attorney/Representative  Average Weekly Wage  Birth Year    C-2 Date  \
# 0                       N                  NaN      2003.0  2023-01-02
# 1                       N                  NaN      2003.0  2023-01-02
# 2                       N                  0.0      1963.0  2022-12-31
# 3                       N                  0.0         0.0  2023-01-02
# 4                       N                  0.0      1997.0  2022-12-31
#
#   C-3 Date                 Carrier Name  ... Medical Fee Region  \
# 0      NaN    INDEMNITY INSURANCE CO OF  ...                 IV
# 1      NaN      A I U INSURANCE COMPANY  ...                 IV
# 2      NaN    AMGUARD INSURANCE COMPANY  ...                III
# 3      NaN  INDEMNITY INS. OF N AMERICA  ...                 IV
# 4      NaN   NEW HAMPSHIRE INSURANCE CO  ...                 IV
#
#    OIICS Nature of Injury Description WCIO Cause of Injury Code  \
# 0                                 NaN                      31.0
# 1                                 NaN                      75.0
# 2                                 NaN                      68.0
# 3                                 NaN                      25.0
# 4                                 NaN                      79.0
#
#    WCIO Cause of Injury Description WCIO Nature of Injury Code  \
# 0           FALL, SLIP OR TRIP, NOC                       10.0
# 1          FALLING OR FLYING OBJECT                       10.0
# 2                 STATIONARY OBJECT                       49.0
# 3  FROM DIFFERENT LEVEL (ELEVATION)                       10.0
# 4    OBJECT BEING LIFTED OR HANDLED                       40.0
#
#   WCIO Nature of Injury Description WCIO Part Of Body Code  \
# 0                         CONTUSION                   54.0
# 1                         CONTUSION                   10.0
# 2                    SPRAIN OR TEAR                   62.0
# 3                         CONTUSION                   53.0
# 4                        LACERATION                   37.0
#
#    WCIO Part Of Body Description  Zip Code Number of Dependents
# 0                      LOWER LEG     10466                    1
# 1           MULTIPLE HEAD INJURY     11691                    1
# 2                       BUTTOCKS     10604                    0
# 3                           KNEE     11411                    6
# 4                          THUMB     11212                    5
#
# [5 rows x 30 columns]

# %% [markdown]
# <a class="anchor" id="briefanalysis">
#
# ## 1.3. Brief Priliminary Analysis
#
# </a>

# %%
print(train.columns)
print("----------------------------------------------")
print(test.columns)
# Out:
# Index(['Accident Date', 'Age at Injury', 'Alternative Dispute Resolution',
#        'Assembly Date', 'Attorney/Representative', 'Average Weekly Wage',
#        'Birth Year', 'C-2 Date', 'C-3 Date', 'Carrier Name', 'Carrier Type',
#        'Claim Identifier', 'Claim Injury Type', 'County of Injury',
#        'COVID-19 Indicator', 'District Name', 'First Hearing Date', 'Gender',
#        'IME-4 Count', 'Industry Code', 'Industry Code Description',
#        'Medical Fee Region', 'OIICS Nature of Injury Description',
#        'WCIO Cause of Injury Code', 'WCIO Cause of Injury Description',
#        'WCIO Nature of Injury Code', 'WCIO Nature of Injury Description',
#        'WCIO Part Of Body Code', 'WCIO Part Of Body Description', 'Zip Code',
#        'Agreement Reached', 'WCB Decision', 'Number of Dependents'],
#       dtype='object')
# ----------------------------------------------
# Index(['Accident Date', 'Age at Injury', 'Alternative Dispute Resolution',
#        'Assembly Date', 'Attorney/Representative', 'Average Weekly Wage',
#        'Birth Year', 'C-2 Date', 'C-3 Date', 'Carrier Name', 'Carrier Type',
#        'Claim Identifier', 'County of Injury', 'COVID-19 Indicator',
#        'District Name', 'First Hearing Date', 'Gender', 'IME-4 Count',
#        'Industry Code', 'Industry Code Description', 'Medical Fee Region',
#        'OIICS Nature of Injury Description', 'WCIO Cause of Injury Code',
#        'WCIO Cause of Injury Description', 'WCIO Nature of Injury Code',
#        'WCIO Nature of Injury Description', 'WCIO Part Of Body Code',
#        'WCIO Part Of Body Description', 'Zip Code', 'Number of Dependents'],
#       dtype='object')

# %% [markdown]
# Checking data types:

# %%
print(train.info())
print("------------------------------------------")
print(test.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 593471 entries, 0 to 593470
# Data columns (total 33 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   Accident Date                       570337 non-null  object
#  1   Age at Injury                       574026 non-null  float64
#  2   Alternative Dispute Resolution      574026 non-null  object
#  3   Assembly Date                       593471 non-null  object
#  4   Attorney/Representative             574026 non-null  object
#  5   Average Weekly Wage                 545375 non-null  float64
#  6   Birth Year                          544948 non-null  float64
#  7   C-2 Date                            559466 non-null  object
#  8   C-3 Date                            187245 non-null  object
#  9   Carrier Name                        574026 non-null  object
#  10  Carrier Type                        574026 non-null  object
#  11  Claim Identifier                    593471 non-null  int64
#  12  Claim Injury Type                   574026 non-null  object
#  13  County of Injury                    574026 non-null  object
#  14  COVID-19 Indicator                  574026 non-null  object
#  15  District Name                       574026 non-null  object
#  16  First Hearing Date                  150798 non-null  object
#  17  Gender                              574026 non-null  object
#  18  IME-4 Count                         132803 non-null  float64
#  19  Industry Code                       564068 non-null  float64
#  20  Industry Code Description           564068 non-null  object
#  21  Medical Fee Region                  574026 non-null  object
#  22  OIICS Nature of Injury Description  0 non-null       float64
#  23  WCIO Cause of Injury Code           558386 non-null  float64
#  24  WCIO Cause of Injury Description    558386 non-null  object
#  25  WCIO Nature of Injury Code          558369 non-null  float64
#  26  WCIO Nature of Injury Description   558369 non-null  object
#  27  WCIO Part Of Body Code              556944 non-null  float64
#  28  WCIO Part Of Body Description       556944 non-null  object
#  29  Zip Code                            545389 non-null  object
#  30  Agreement Reached                   574026 non-null  float64
#  31  WCB Decision                        574026 non-null  object
#  32  Number of Dependents                574026 non-null  float64
# dtypes: float64(11), int64(1), object(21)
# memory usage: 149.4+ MB
# None
# ------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 387975 entries, 0 to 387974
# Data columns (total 30 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   Accident Date                       385531 non-null  object
#  1   Age at Injury                       387975 non-null  int64
#  2   Alternative Dispute Resolution      387975 non-null  object
#  3   Assembly Date                       387975 non-null  object
#  4   Attorney/Representative             387975 non-null  object
#  5   Average Weekly Wage                 368771 non-null  float64
#  6   Birth Year                          368505 non-null  float64
#  7   C-2 Date                            378841 non-null  object
#  8   C-3 Date                            85216 non-null   object
#  9   Carrier Name                        387975 non-null  object
#  10  Carrier Type                        387975 non-null  object
#  11  Claim Identifier                    387975 non-null  int64
#  12  County of Injury                    387975 non-null  object
#  13  COVID-19 Indicator                  387975 non-null  object
#  14  District Name                       387975 non-null  object
#  15  First Hearing Date                  43028 non-null   object
#  16  Gender                              387975 non-null  object
#  17  IME-4 Count                         35249 non-null   float64
#  18  Industry Code                       380239 non-null  float64
#  19  Industry Code Description           380239 non-null  object
#  20  Medical Fee Region                  387975 non-null  object
#  21  OIICS Nature of Injury Description  0 non-null       float64
#  22  WCIO Cause of Injury Code           377627 non-null  float64
#  23  WCIO Cause of Injury Description    377627 non-null  object
#  24  WCIO Nature of Injury Code          377415 non-null  float64
#  25  WCIO Nature of Injury Description   377415 non-null  object
#  26  WCIO Part Of Body Code              378426 non-null  float64
#  27  WCIO Part Of Body Description       378426 non-null  object
#  28  Zip Code                            368633 non-null  object
#  29  Number of Dependents                387975 non-null  int64
# dtypes: float64(8), int64(3), object(19)
# memory usage: 88.8+ MB
# None

# %% [markdown]
# Looking at missing values:

# %%
print("The missing values for our train set are:\n",train.isna().sum())
print("--------------------------------------------------")
print("The missing values for our test set are:\n", test.isna().sum())
# Out:
# The missing values for our train set are:
#  Accident Date                          23134
# Age at Injury                          19445
# Alternative Dispute Resolution         19445
# Assembly Date                              0
# Attorney/Representative                19445
# Average Weekly Wage                    48096
# Birth Year                             48523
# C-2 Date                               34005
# C-3 Date                              406226
# Carrier Name                           19445
# Carrier Type                           19445
# Claim Identifier                           0
# Claim Injury Type                      19445
# County of Injury                       19445
# COVID-19 Indicator                     19445
# District Name                          19445
# First Hearing Date                    442673
# Gender                                 19445
# IME-4 Count                           460668
# Industry Code                          29403
# Industry Code Description              29403
# Medical Fee Region                     19445
# OIICS Nature of Injury Description    593471
# WCIO Cause of Injury Code              35085
# WCIO Cause of Injury Description       35085
# WCIO Nature of Injury Code             35102
# WCIO Nature of Injury Description      35102
# WCIO Part Of Body Code                 36527
# WCIO Part Of Body Description          36527
# Zip Code                               48082
# Agreement Reached                      19445
# WCB Decision                           19445
# Number of Dependents                   19445
# dtype: int64
# --------------------------------------------------
# The missing values for our test set are:
#  Accident Date                           2444
# Age at Injury                              0
# Alternative Dispute Resolution             0
# Assembly Date                              0
# Attorney/Representative                    0
# Average Weekly Wage                    19204
# Birth Year                             19470
# C-2 Date                                9134
# C-3 Date                              302759
# Carrier Name                               0
# Carrier Type                               0
# Claim Identifier                           0
# County of Injury                           0
# COVID-19 Indicator                         0
# District Name                              0
# First Hearing Date                    344947
# Gender                                     0
# IME-4 Count                           352726
# Industry Code                           7736
# Industry Code Description               7736
# Medical Fee Region                         0
# OIICS Nature of Injury Description    387975
# WCIO Cause of Injury Code              10348
# WCIO Cause of Injury Description       10348
# WCIO Nature of Injury Code             10560
# WCIO Nature of Injury Description      10560
# WCIO Part Of Body Code                  9549
# WCIO Part Of Body Description           9549
# Zip Code                               19342
# Number of Dependents                       0
# dtype: int64

# %% [markdown]
# Brief statistical Overview:

# %%
# For our numerical features:
train.describe().T
# Out:
#                                        count          mean           std  \
# Age at Injury                       574026.0  4.211427e+01  1.425643e+01
# Average Weekly Wage                 545375.0  4.910883e+02  6.092918e+03
# Birth Year                          544948.0  1.886768e+03  4.146444e+02
# Claim Identifier                    593471.0  2.366760e+07  1.079271e+08
# IME-4 Count                         132803.0  3.207337e+00  2.832303e+00
# Industry Code                       564068.0  5.864531e+01  1.964417e+01
# OIICS Nature of Injury Description       0.0           NaN           NaN
# WCIO Cause of Injury Code           558386.0  5.438114e+01  2.587428e+01
# WCIO Nature of Injury Code          558369.0  4.101384e+01  2.220752e+01
# WCIO Part Of Body Code              556944.0  3.973815e+01  2.236594e+01
# Agreement Reached                   574026.0  4.666513e-02  2.109208e-01
# Number of Dependents                574026.0  3.006559e+00  2.000801e+00
#
#                                           min        25%        50%  \
# Age at Injury                             0.0       31.0       42.0
# Average Weekly Wage                       0.0        0.0        0.0
# Birth Year                                0.0     1965.0     1977.0
# Claim Identifier                    5393066.0  5593414.5  5791212.0
# IME-4 Count                               1.0        1.0        2.0
# Industry Code                            11.0       45.0       61.0
# OIICS Nature of Injury Description        NaN        NaN        NaN
# WCIO Cause of Injury Code                 1.0       31.0       56.0
# WCIO Nature of Injury Code                1.0       16.0       49.0
# WCIO Part Of Body Code                   -9.0       33.0       38.0
# Agreement Reached                         0.0        0.0        0.0
# Number of Dependents                      0.0        1.0        3.0
#
#                                           75%          max
# Age at Injury                            54.0        117.0
# Average Weekly Wage                     841.0    2828079.0
# Birth Year                             1989.0       2018.0
# Claim Identifier                    5991000.5  999891667.0
# IME-4 Count                               4.0         73.0
# Industry Code                            71.0         92.0
# OIICS Nature of Injury Description        NaN          NaN
# WCIO Cause of Injury Code                75.0         99.0
# WCIO Nature of Injury Code               52.0         91.0
# WCIO Part Of Body Code                   53.0         99.0
# Agreement Reached                         0.0          1.0
# Number of Dependents                      5.0          6.0

# %% [markdown]
# For our object data types:

# %%
train.describe(include="object").T
# Out:
#                                     count unique  \
# Accident Date                      570337   5539
# Alternative Dispute Resolution     574026      3
# Assembly Date                      593471   1096
# Attorney/Representative            574026      2
# C-2 Date                           559466   2475
# C-3 Date                           187245   1648
# Carrier Name                       574026   2046
# Carrier Type                       574026      8
# Claim Injury Type                  574026      8
# County of Injury                   574026     63
# COVID-19 Indicator                 574026      2
# District Name                      574026      8
# First Hearing Date                 150798   1094
# Gender                             574026      4
# Industry Code Description          564068     20
# Medical Fee Region                 574026      5
# WCIO Cause of Injury Description   558386     74
# WCIO Nature of Injury Description  558369     56
# WCIO Part Of Body Description      556944     54
# Zip Code                           545389  10060
# WCB Decision                       574026      1
#
#                                                                  top    freq
# Accident Date                                             2020-03-01    1245
# Alternative Dispute Resolution                                     N  571412
# Assembly Date                                             2020-03-06    1422
# Attorney/Representative                                            N  392291
# C-2 Date                                                  2021-05-11    1847
# C-3 Date                                                  2021-04-21     350
# Carrier Name                                    STATE INSURANCE FUND  111144
# Carrier Type                                             1A. PRIVATE  285368
# Claim Injury Type                                        2. NON-COMP  291078
# County of Injury                                             SUFFOLK   60430
# COVID-19 Indicator                                                 N  546505
# District Name                                                    NYC  270779
# First Hearing Date                                        2022-04-15     440
# Gender                                                             M  335218
# Industry Code Description          HEALTH CARE AND SOCIAL ASSISTANCE  114339
# Medical Fee Region                                                IV  265981
# WCIO Cause of Injury Description                             LIFTING   46610
# WCIO Nature of Injury Description                     STRAIN OR TEAR  153373
# WCIO Part Of Body Description                        LOWER BACK AREA   51862
# Zip Code                                                       11236    3302
# WCB Decision                                        Not Work Related  574026

# %% [markdown]
# <a class="anchor" id="notes">
#
# ## 1.4. Notes
#
# </a>

# %% [markdown]
# Brief preliminary analysis on our data given the Metadata, and initial structural analysis:
# - It seems our test set, is clearly more reduced in terms of rows by approximately 200k. Evidently, our test set does not include 3 features, namely: "Claim Injury Type" , "WCB Decision" and "Agreement Reached". For our project, we are looking to make predictions on "Claim Injury Type".
# - So, we are looking at 33 features in total. We know that we will most likely need to reduce this number, for modeling purposes, not every variable is going to be important. We know that the Curse of Dimensionality downgrades models performance.
# - We also note the existance of many missing values mainly in training data which we will be exploring and solving in the preprocessing part.

# %% [markdown]
#  <a class="anchor" id="eda">
#
# # 2. Exploratory Data Analysis
#
# </a>

# %% [markdown]
# In this first instance, a number of data types will be altered in order to facilitate distribution among the various plots that will be presented. So the division will essentially be made in 3 ways, values consisting of Integers and Floats, values relating to Dates (Datetime) where we will analyse the values by year and values relating to objects or categories.
#
#
# - Integer and Float - Histogram, Box Plot, Histogram related with the target variable.
# - Dates - Histogram, Box Plot, Histogram related with the target variable.
# - Objects and Categories - Histogram and Circular Graph.
#
# We will use the general functions whenever possible, however in cases where there is disformatting for any reason, such as large amounts of values, we will apply a specific function to that Feature.

# %%
#I created this copy to use it for EDA
train_copy = train.copy()

# %%
# Converting the datatype of date features from object to datetime

train_copy['Accident Date'] = pd.to_datetime(train_copy['Accident Date'])
train_copy['Assembly Date'] = pd.to_datetime(train_copy['Assembly Date'])
train_copy['C-2 Date'] = pd.to_datetime(train_copy['C-2 Date'])
train_copy['C-3 Date'] = pd.to_datetime(train_copy['C-3 Date'])
train_copy['First Hearing Date'] = pd.to_datetime(train_copy['First Hearing Date'])

# %%
# Converting the datatype of categorical features from object to category

train_copy['Carrier Type'] = train_copy['Carrier Type'].astype('category')
train_copy['Agreement Reached'] = train_copy['Agreement Reached'].astype('category')
train_copy['WCB Decision'] = train_copy['WCB Decision'].astype('category')
train_copy['COVID-19 Indicator'] = train_copy['COVID-19 Indicator'].astype('category')
train_copy['Gender'] = train_copy['Gender'].astype('category')
train_copy['Attorney/Representative'] = train_copy['Attorney/Representative'].astype('category')
train_copy['Medical Fee Region'] = train_copy['Medical Fee Region'].astype('category')

# %%
#Displaying the results of conversion
print(train_copy.dtypes)
# Out:
# Accident Date                         datetime64[ns]
# Age at Injury                                float64
# Alternative Dispute Resolution                object
# Assembly Date                         datetime64[ns]
# Attorney/Representative                     category
# Average Weekly Wage                          float64
# Birth Year                                   float64
# C-2 Date                              datetime64[ns]
# C-3 Date                              datetime64[ns]
# Carrier Name                                  object
# Carrier Type                                category
# Claim Identifier                               int64
# Claim Injury Type                             object
# County of Injury                              object
# COVID-19 Indicator                          category
# District Name                                 object
# First Hearing Date                    datetime64[ns]
# Gender                                      category
# IME-4 Count                                  float64
# Industry Code                                float64
# Industry Code Description                     object
# Medical Fee Region                          category
# OIICS Nature of Injury Description           float64
# WCIO Cause of Injury Code                    float64
# WCIO Cause of Injury Description              object
# WCIO Nature of Injury Code                   float64
# WCIO Nature of Injury Description             object
# WCIO Part Of Body Code                       float64
# WCIO Part Of Body Description                 object
# Zip Code                                      object
# Agreement Reached                           category
# WCB Decision                                category
# Number of Dependents                         float64
# dtype: object

# %% [markdown]
# <a class="anchor" id="numerical">
#
# ## 2.1 Numerical Visulization
#
# </a>

# %% [markdown]
# ### Numerical Function

# %%
# Create de funtion for the numerical variables
# The function will get 3 parameters:
# - data: DataFrame containing the data in this case it will be train_copy
# - variable: The name of the numeric variable to plot
# - hue: str, optional, the name of the categorical variable for class separation (target variable)
def plot_numeric_variable(data, variable, hue=None):  
    # Setting up the figure with 3 subplots, with the adjusted size of (18, 4)
    fig, ax = plt.subplots(1, 3, figsize=(18, 4))
    # 1st graph. Histogram for the specified variable
    sns.histplot(data=data, x=variable, ax=ax[0], kde=True)
    ax[0].set_title(f"{variable} Distribution")
    ax[0].set_ylabel("Count")
    # 2ng graph. Boxplot for the specified variable
    sns.boxplot(data=data, x=variable, ax=ax[1])
    ax[1].set_title(f"{variable} Boxplot")
    ax[1].set_ylabel("")
    # 3th graph. Histogram for the specified variable by class (if hue is provided)
    if hue:
        sns.histplot(data=data, x=variable, hue=hue, multiple='stack', ax=ax[2], kde=True)
        ax[2].set_title(f"{variable} by {hue}")
    else:
        sns.histplot(data=data, x=variable, ax=ax[2], kde=True)
        ax[2].set_title(f"{variable} Distribution (No Hue)")
    ax[2].set_ylabel("Count")
    # Adjust layout and show
    fig.tight_layout()
    plt.show()

# %% [markdown]
# <a class="anchor" id="age">
#
# ### 2.1.1. Age at Injury
#
# </a>

# %%
plot_numeric_variable(data=train_copy, variable='Age at Injury', hue='Claim Injury Type')

# %% [markdown]
# ##### Values oscillate mostly between 20 and 80. Outliers are quite noticeable from the 85th+ age onwards, through the histogram on the right we can analyse the presence of the NON-COMP and TEMPORARY types which tend to be the most frequent throughout all ages, with a greater focus on the highest peaks. It is also possible to observe several values with 0 which could be an inconsistency in the dataset since no one is injured at work at 0 years old.

# %% [markdown]
# <a class="anchor" id="wage">
#
# ### 2.1.2. Average Weekly Wage
#
# </a>

# %%
#plot_numeric_variable(data=train_copy, variable='Average Weekly Wage', hue='Claim Injury Type')
#Configuração da figura com três subplots
fig, ax = plt.subplots(1, 2, figsize=(18, 5))

# 1. Average Weekly Wage
sns.boxplot(data=train_copy, x='Average Weekly Wage', ax=ax[0])
ax[0].set_title("Average Weekly Wage")
ax[0].set_xlabel("Average Weekly Wage")

# 2. Histograma para Average Weekly Wage
sns.histplot(data=train_copy, x='IME-4 Count', bins=40, ax=ax[1], kde=True)
ax[1].set_title("Average Weekly Wage Histogram")
ax[1].set_xlabel("Average Weekly Wage")
ax[1].set_ylabel("Frequency")


# Ajustar o layout para uma melhor visualização
fig.tight_layout()
plt.show()

# %% [markdown]
# ##### The amount of "missing" values (0s) in this variable really distorts any potential analysis that could be done. The boxplots also indicate a heavy presence of outliers.

# %% [markdown]
# #####

# %% [markdown]
# <a class="anchor" id="birth">
#
# ### 2.1.3. Birth Year
#
# </a>

# %%
# Setting up plots for the 'Birth Year' variable
fig, ax = plt.subplots(1, 3, figsize=(18, 4))

# Define x-axis limits to focus on realistic year range
xlim = (1900, 2025)

# 1. Histogram for Birth Year
sns.histplot(data=train_copy, x='Birth Year', ax=ax[0], kde=True)
ax[0].set_title("Birth Year Distribution")
ax[0].set_ylabel("Count")
ax[0].set_xlim(xlim)

# 2. Boxplot for Birth Year
sns.boxplot(data=train_copy, x='Birth Year', ax=ax[1])
ax[1].set_title("Birth Year Boxplot")
ax[1].set_xlim(xlim)

# 3. Histogram for Birth Year by Claim Injury Type (or another target variable)
sns.histplot(data=train_copy, x='Birth Year', hue='Claim Injury Type', multiple='stack', ax=ax[2], kde=True)
ax[2].set_title("Birth Year by Claim Injury Type")
ax[2].set_ylabel("Count")
ax[2].set_xlim(xlim)

# Adjust layout for better visualization
fig.tight_layout()
plt.show()

# %% [markdown]
# ##### Quite a few outliers present in the years before 1930, which can be errors in the dataset since it is improbable that someone can practice a profession at that age. Also we can note most of our fall between 1950 and 2000, which are representative of the 2nd and 3rd quartiles.

# %% [markdown]
# <a class="anchor" id="IME">
#
# ### 2.1.4. IME-4 Count
#
# </a>

# %%
# Configuração da figura com três subplots
fig, ax = plt.subplots(1, 2, figsize=(18, 5))

# 1. Boxplot para IME-4 Count
sns.boxplot(data=train_copy, x='IME-4 Count', ax=ax[0])
ax[0].set_title("IME-4 Count Boxplot")
ax[0].set_xlabel("IME-4 Count")

# 2. Histograma para IME-4 Count
sns.histplot(data=train_copy, x='IME-4 Count', bins=40, ax=ax[1], kde=True)
ax[1].set_title("IME-4 Count Histogram")
ax[1].set_xlabel("IME-4 Count")
ax[1].set_ylabel("Frequency")


# Ajustar o layout para uma melhor visualização
plt.show()

# %% [markdown]
# ##### Quite a lot of values between 1 and 2 and a constant and sharp decrease up to 10, from then on and from the in-depth analysis of the boxplot it can be concluded that all the values are considered outliers. A more precise analysis on handling outliers will be done later on.

# %% [markdown]
# <a class="anchor" id="industrycount">
#
# ### 2.1.5. Industry Count
#
# </a>

# %%
plot_numeric_variable(data=train_copy, variable='Industry Code', hue='Claim Injury Type')

# %% [markdown]
# ##### The most common industries have code 60 and codes between 40 and 50, and the boxplot shows that there are no outliers in this feature.

# %% [markdown]
# <a class="anchor" id="causecode">
#
# ### 2.1.6. WCIO Cause of Injury Code
#
# </a>

# %%
plot_numeric_variable(data=train_copy, variable='WCIO Cause of Injury Code', hue='Claim Injury Type')

# %% [markdown]
# ##### Column with no outliers that need to be dealt with, however it is worth noting the 2 peaks in the WCIO Cause of Injury Code of 25 and 58 that contribute greatly to the average being around these values.

# %% [markdown]
# <a class="anchor" id="naturecode">
#
# ### 2.1.7. WCIO Nature of Injury Code
#
# </a>

# %%
plot_numeric_variable(data=train_copy, variable='WCIO Nature of Injury Code', hue='Claim Injury Type')

# %% [markdown]
# ##### In the case of the WCIO Nature of Injury Code feature, we can highlight the absence of outliers and the presence of a peak in the code of codes around 50.

# %% [markdown]
# <a class="anchor" id="bodycode">
#
# ### 2.1.8. WCIO Part of Body Code
#
# </a>

# %%
plot_numeric_variable(data=train_copy, variable='WCIO Part Of Body Code', hue='Claim Injury Type')

# %% [markdown]
# ##### In the case of the WCIO Part Of Body Code we can highlight the outliers of 0 and around 100, we can also consider that the codes between 20 and 40 correspond to the parts of the body that are most often injured

# %% [markdown]
# <a class="anchor" id="dependents">
#
# ### 2.1.9. Number of Dependents
#
# </a>

# %%
plot_numeric_variable(data=train_copy, variable='Number of Dependents', hue='Claim Injury Type')

# %% [markdown]
# ##### The number of dependents varies between 0 and 6 and the distribution seems to be quite similar, increasing slightly when there are 6 dependents, which is a fairly residual value, there is no outliers also. This seems to be an atypical variable. The distribution of dependents between 0-6 seems symetrical across every value which seems odd.

# %% [markdown]
#  <a class="anchor" id="dates">
#
# ## 2.2. Dates Visualization (Distribution by Year)
#
# </a>

# %% [markdown]
# ### Year Funtion

# %%
# Generate the funtion for the datetype
# The function will get 3 parameters:
# - data: DataFrame containing the data in this case it will be train_copy
# - datetime_col: The name of the datetyme variable to plot in this particular case will focus just on years 
# - hue: str, optional, the name of the categorical variable for class separation (target variable)
def plot_year_distribution_with_target(data, datetime_col, hue=None):   
    # Check if the column is in datetime format
    if not pd.api.types.is_datetime64_any_dtype(data[datetime_col]):
        data[datetime_col] = pd.to_datetime(data[datetime_col], errors='coerce')    
    # Extract the year from the datetime column
    data[f'{datetime_col} Year'] = data[datetime_col].dt.year
    # Set up the figure with three subplots with the size of (18, 15)
    fig, ax = plt.subplots(1, 3, figsize=(18, 5))
    # 1. Histogram for the year
    sns.histplot(data=data, x=f'{datetime_col} Year', bins=30, ax=ax[0], kde=True)
    ax[0].set_title(f"{datetime_col} Year Histogram")
    ax[0].set_xlabel(f"{datetime_col} Year")
    ax[0].set_ylabel("Frequency")
    ax[0].xaxis.set_major_locator(plt.MaxNLocator(integer=True))  # Set x-axis to show only integer years
    # 2. Boxplot for the year (placed in the middle)
    sns.boxplot(data=data, x=f'{datetime_col} Year', ax=ax[1])
    ax[1].set_title(f"{datetime_col} Year Boxplot")
    ax[1].set_xlabel(f"{datetime_col} Year")
    ax[1].xaxis.set_major_locator(plt.MaxNLocator(integer=True))  # Set x-axis to show only integer years
    # 3. Class-separated Histogram for the year (if hue is provided)
    if hue:
        sns.histplot(data=data, x=f'{datetime_col} Year', hue=hue, multiple='stack', bins=30, ax=ax[2], kde=True)
        ax[2].set_title(f"{datetime_col} Year by {hue}")
        ax[2].set_ylabel("Count")
        ax[2].set_xlabel(f"{datetime_col} Year")
        ax[2].xaxis.set_major_locator(plt.MaxNLocator(integer=True))  # Set x-axis to show only integer years
    else:
        sns.histplot(data=data, x=f'{datetime_col} Year', bins=30, ax=ax[2], kde=True)
        ax[2].set_title(f"{datetime_col} Year Distribution (No Hue)")
        ax[2].set_ylabel("Count")
        ax[2].set_xlabel(f"{datetime_col} Year")
        ax[2].xaxis.set_major_locator(plt.MaxNLocator(integer=True))  # Set x-axis to show only integer years
    plt.show()

# %%
train_copy
# Out:
#        Accident Date  Age at Injury Alternative Dispute Resolution  \
# 0         2019-12-30           31.0                              N
# 1         2019-08-30           46.0                              N
# 2         2019-12-06           40.0                              N
# 3                NaT            NaN                            NaN
# 4         2019-12-30           61.0                              N
# ...              ...            ...                            ...
# 593466           NaT            NaN                            NaN
# 593467    2022-12-13           72.0                              N
# 593468           NaT            NaN                            NaN
# 593469           NaT            NaN                            NaN
# 593470           NaT            NaN                            NaN
#
#        Assembly Date Attorney/Representative  Average Weekly Wage  Birth Year  \
# 0         2020-01-01                       N                 0.00      1988.0
# 1         2020-01-01                       Y              1745.93      1973.0
# 2         2020-01-01                       N              1434.80      1979.0
# 3         2020-01-01                     NaN                  NaN         NaN
# 4         2020-01-01                       N                  NaN      1958.0
# ...              ...                     ...                  ...         ...
# 593466    2022-12-31                     NaN                  NaN         NaN
# 593467    2022-12-31                       N                 0.00      1950.0
# 593468    2022-12-31                     NaN                  NaN         NaN
# 593469    2022-12-31                     NaN                  NaN         NaN
# 593470    2022-12-31                     NaN                  NaN         NaN
#
#          C-2 Date   C-3 Date                   Carrier Name  ...  \
# 0      2019-12-31        NaT     NEW HAMPSHIRE INSURANCE CO  ...
# 1      2020-01-01 2020-01-14   ZURICH AMERICAN INSURANCE CO  ...
# 2      2020-01-01        NaT      INDEMNITY INSURANCE CO OF  ...
# 3             NaT        NaT                            NaN  ...
# 4      2019-12-31        NaT           STATE INSURANCE FUND  ...
# ...           ...        ...                            ...  ...
# 593466        NaT        NaT                            NaN  ...
# 593467 2022-12-31        NaT  TECHNOLOGY INSURANCE CO. INC.  ...
# 593468        NaT        NaT                            NaN  ...
# 593469        NaT        NaT                            NaN  ...
# 593470        NaT        NaT                            NaN  ...
#
#        WCIO Cause of Injury Code  WCIO Cause of Injury Description  \
# 0                           27.0      FROM LIQUID OR GREASE SPILLS
# 1                           97.0                 REPETITIVE MOTION
# 2                           79.0    OBJECT BEING LIFTED OR HANDLED
# 3                            NaN                               NaN
# 4                           16.0   HAND TOOL, UTENSIL; NOT POWERED
# ...                          ...                               ...
# 593466                       NaN                               NaN
# 593467                      25.0  FROM DIFFERENT LEVEL (ELEVATION)
# 593468                       NaN                               NaN
# 593469                       NaN                               NaN
# 593470                       NaN                               NaN
#
#        WCIO Nature of Injury Code WCIO Nature of Injury Description  \
# 0                            10.0                         CONTUSION
# 1                            49.0                    SPRAIN OR TEAR
# 2                             7.0                        CONCUSSION
# 3                             NaN                               NaN
# 4                            43.0                          PUNCTURE
# ...                           ...                               ...
# 593466                        NaN                               NaN
# 593467                       90.0   MULTIPLE PHYSICAL INJURIES ONLY
# 593468                        NaN                               NaN
# 593469                        NaN                               NaN
# 593470                        NaN                               NaN
#
#        WCIO Part Of Body Code WCIO Part Of Body Description Zip Code  \
# 0                        62.0                      BUTTOCKS    13662
# 1                        38.0                   SHOULDER(S)    14569
# 2                        10.0          MULTIPLE HEAD INJURY    12589
# 3                         NaN                           NaN      NaN
# 4                        36.0                     FINGER(S)    12603
# ...                       ...                           ...      ...
# 593466                    NaN                           NaN      NaN
# 593467                   -9.0                      MULTIPLE    12779
# 593468                    NaN                           NaN      NaN
# 593469                    NaN                           NaN      NaN
# 593470                    NaN                           NaN      NaN
#
#        Agreement Reached      WCB Decision  Number of Dependents
# 0                    0.0  Not Work Related                   1.0
# 1                    1.0  Not Work Related                   4.0
# 2                    0.0  Not Work Related                   6.0
# 3                    NaN               NaN                   NaN
# 4                    0.0  Not Work Related                   1.0
# ...                  ...               ...                   ...
# 593466               NaN               NaN                   NaN
# 593467               0.0  Not Work Related                   3.0
# 593468               NaN               NaN                   NaN
# 593469               NaN               NaN                   NaN
# 593470               NaN               NaN                   NaN
#
# [593471 rows x 33 columns]

# %% [markdown]
#  <a class="anchor" id="accidentdate">
#
# ### 2.2.1 Accident Date
#
# </a>

# %%
plot_year_distribution_with_target(data=train_copy, datetime_col='Accident Date', hue='Claim Injury Type')

# %% [markdown]
# ##### Presence of numerous outliers before 2016, outliers that have been present since the 1960s, values accumulated between 2020 and 2022 again, however there are also residual values after 2022 until 2024.

# %% [markdown]
#  <a class="anchor" id="assemblydate">
#
# ### 2.2.2 Assembly Date
#
# </a>

# %%
plot_year_distribution_with_target(data=train_copy, datetime_col='Assembly Date', hue='Claim Injury Type')

# %% [markdown]
# ##### There are no outliers and Assembly Date only takes values from 2020 to 2022, for our train set, as we know test set holds different date values.

# %% [markdown]
#  <a class="anchor" id="c2date">
#
# ### 2.2.3 C-2 Date
#
# </a>

# %%
plot_year_distribution_with_target(data=train_copy, datetime_col='C-2 Date', hue='Claim Injury Type')

# %% [markdown]
# ##### Constant outliers before 2018, until 1995, values are concentrated between 2020 and 2022.

# %% [markdown]
#  <a class="anchor" id="c3date">
#
# ### 2.2.4 C-3 Date
#
# </a>

# %%
plot_year_distribution_with_target(data=train_copy, datetime_col='C-3 Date', hue='Claim Injury Type')

# %% [markdown]
# ##### Presence of outliers before 2016, a very distant outlier before 1995, as can be seen in the boxplot, the average C-3 Date is around 2020 and 2022.

# %% [markdown]
#  <a class="anchor" id="firsthearingdate">
#
# ### 2.2.5 First Hearing Date
#
# </a>

# %%
plot_year_distribution_with_target(data=train_copy, datetime_col='First Hearing Date', hue='Claim Injury Type')

# %% [markdown]
# ##### There are no outliers in this feature, however the years 2021, 2022 and 2023 are the most relevant for this feature.

# %% [markdown]
#  <a class="anchor" id="categorical">
#
# ## 2.3 Categorical Visualization
#
# </a>

# %% [markdown]
# ### Categorical Funtion

# %%
# Generate the function for categorical variables
# We get 2 parameters:
#  - data: DataFrame containing the data
#  - categorical_var: str, the name of the categorical variable to analyze
def plot_categorical_analysis(data, categorical_var):
    # Get value counts for the categorical variable
    value_counts = data[categorical_var].value_counts()    
    # Determine the number of values to show in the pie chart (10 or fewer)
    # We do that to get a better view about features that have a lot of values
    top_values = value_counts.head(10)    
    # Set up the figure with two subplots, giving more space to the pie chart
    fig, ax = plt.subplots(1, 2, figsize=(18, 7), gridspec_kw={'width_ratios': [1, 1.5]})
    # 1. Histogram (Countplot)
    sns.countplot(data=data, x=categorical_var, ax=ax[0], palette="Blues")
    ax[0].set_title(f"{categorical_var} Distribution")
    ax[0].set_xlabel(categorical_var)
    ax[0].set_ylabel("Count")
    ax[0].tick_params(axis='x', rotation=65)
    # 2. Pie Chart for Top 10 (or fewer) Values with blue colors
    colors = sns.color_palette("Blues", len(top_values))
    ax[1].pie(top_values, labels=top_values.index, autopct='%1.1f%%', startangle=140, colors=colors, textprops={'fontsize': 10})
    ax[1].set_title(f"Top 10 {categorical_var} Values" if len(top_values) == 10 else f"All {categorical_var} Values")
    # Adjust layout for better visualization
    plt.show()

# %% [markdown]
#  <a class="anchor" id="attorney">
#
# ### 2.3.1 Attorney/representative
#
# </a>

# %%
plot_categorical_analysis(data=train_copy, categorical_var='Attorney/Representative')

# %% [markdown]
# ##### Presence of only 2 values: ‘N’ or ‘Y’, with somewhat unbalanced proportions (70/30).

# %% [markdown]
#  <a class="anchor" id="carrier">
#
# ### 2.3.2 Carrier Name
#
# </a>

# %% [markdown]
# ##### The Carrier Name feature has many different values and it is extremely complicated to present this feature in histograms and circular graphs, however these values may have to be treated in some way.

# %% [markdown]
#  <a class="anchor" id="resolution">
#
# ### 2.3.3 Alternative Dispute Resolution
#
# </a>

# %%
plot_categorical_analysis(data=train_copy, categorical_var='Alternative Dispute Resolution')

# %% [markdown]
# ##### Extremely high proportion for N values, accounting for 99.5 per cent of this feature, very low Y values and completely residual U values.

# %% [markdown]
#  <a class="anchor" id="carriertype">
#
# ### 2.3.4 Carrier Type
#
# </a>

# %%
plot_categorical_analysis(data=train_copy, categorical_var='Carrier Type')

# %% [markdown]
# ##### Analysing the Carrier Type variable, we can see that 1A PRIVATE, 2A. SIF, 4A. SELF PRIVATE and 3A. SELF PUBLIC account for the overwhelming majority of values, while the other 4 variables have rather residual values that may have to be dealt with.

# %% [markdown]
#  <a class="anchor" id="claimtype">
#
# ### 2.3.5 Claim Injury Type
#
# </a>

# %%
plot_categorical_analysis(data=train_copy, categorical_var='Claim Injury Type')

# %% [markdown]
# ##### With regard to the target variable, around 50 % of the values correspond to 2.NON-COMP, while the values 8. DEATH and 7. PTD have very residual values. Very important graph to once more realize the class imbalance we are dealing with.

# %% [markdown]
#  <a class="anchor" id="county">
#
# ### 2.3.6 County of Injury
#
# </a>

# %%
plot_categorical_analysis(data=train_copy, categorical_var='County of Injury')

# %% [markdown]
# ##### A lot of values in the County of Injury, many of which are quite small, may have to be dealt with by adding a new value called ‘other’ to make it easier to encode this variable.

# %% [markdown]
#  <a class="anchor" id="covid">
#
# ### 2.3.7 COVID-19 Indicator
#
# </a>

# %%
plot_categorical_analysis(data=train_copy, categorical_var='COVID-19 Indicator')

# %% [markdown]
# ##### A feature that only shows 2 values, i.e. whether or not the subject associated with the accident had COVID-19, in around 95.2 per cent of cases they did not, the 4.8 per cent can be considered a relatively residual value.

# %% [markdown]
#  <a class="anchor" id="district">
#
# ### 2.3.8 District Name
#
# </a>

# %%
plot_categorical_analysis(data=train_copy, categorical_var='District Name')

# %% [markdown]
# ##### Presence of 8 different districts where only STATEWIDE shows very low values

# %% [markdown]
#  <a class="anchor" id="gender">
#
# ### 2.3.9 Gender
#
# </a>

# %%
plot_categorical_analysis(data=train_copy, categorical_var='Gender')

# %% [markdown]
# ##### Extremely residual values of U and X are mostly associated with M or F representing male and female respectively, so in order to optimise the model it will be necessary to deal with the residual values, especially the value of X.

# %% [markdown]
#  <a class="anchor" id="agreement">
#
# ### 2.3.10 Agreement reached
#
# </a>

# %%
plot_categorical_analysis(data=train_copy, categorical_var='Agreement Reached')

# %% [markdown]
# ##### Binary variable where about 95 per cent of the values are 0.0 and only about 5 per cent are 1.0.

# %% [markdown]
#  <a class="anchor" id="preprocessing">
#
# # 3. Data Preproceesing
#
# </a>

# %% [markdown]
# A key step in preprocessing is handling incoherences, missing values, outliers and do feature engineering. Nevertheless, any preprocessing we do on our train set, will need to be replicated on our test so our model can evaluate correctly. But we need to be careful, meaning that any transformations like scaling, encoding or imputing missing values should be calculated based on the training data only.
# - After fitting the preprocessing steps in the training data, we can apply these exact same steps to our test set, without refitting. This ensures that the test data has identical transformations and remains a true "holdout" set.
# - This is major in terms of avoiding data leakage, which is the risk of our model "seeing" information from test set, leading to over-optimistic performance.
# - One goal is also to replicate our validation set as closely as possible to our test set, to get the best generalization possible.
# - To recapitulate: Fit all transformations on training set and apply these without refitting to the test set.

# %% [markdown]
#  <a class="anchor" id="incoherences">
#
# ## 3.1 Splitting Training Data and Addressing Incoherences
#
# </a>

# %% [markdown]
# During our EDA, we noticed some incoherences which will be dealt with it before treating outliers and missing values:
#
# <span style="color:red; font-weight:bold">The first major Issue</span> was that we had few rows in which we had missing values in all features except for Claim Identifier and Assembly Date. <br>
# <span style="color:green; font-weight:bold">Proposed Solution:</span> Since there is no real information we can extract from these rows we decided to drop them before we split the data (nearly 20K rows were removed)

# %%
# Excluding the features we do not wish to look at since there are no missing values present
excluded_features = ["Assembly Date", "Claim Identifier"]
cond = train.drop(columns=excluded_features).isna().all(axis=1)


train = train[~cond]
print(train.shape)
# We succesfully removed rows for which no information was available.
# Out:
# (574026, 33)

# %% [markdown]
# #### Splitting Training Data

# %% [markdown]
# After this first problem, we fortunately eliminated a lot of missing values present. And we can already split our dataset safety.

# %%
# Assuming train is your DataFrame and 'Claim Injury Type' is the target column
X = train.drop(columns="Claim Injury Type")  # Features
y = train["Claim Injury Type"]  # Target

# Perform the split
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.25, random_state=42, shuffle=True, stratify=y)

# %% [markdown]
# <span style="color:red; font-weight:bold">The second major Issue:</span> We found that the feature "OIICS Nature of Injury Description" contains no value in all the rows. <br>
# <span style="color:green; font-weight:bold">Proposed Solution:</span>We explored the website through the link provided in metadatas. However, this feature does not contribute any useful information to our dataset, and its lack of variation makes it unhelpful for modeling so we decided to drop it from training, validation and test dataset

# %%
# Dropping from Train and Validation.
X_train = X_train.drop(columns="OIICS Nature of Injury Description")
X_val = X_val.drop(columns="OIICS Nature of Injury Description")

# %% [markdown]
# <span style="color:red; font-weight:bold">The third major Issue:</span>Third major incoherence arises when we take a deeper look at our metadata, and our data sets. The features "Agreement Reached" and "WCB Decision" are not present in our test set (as well as our target logically), we should therefore drop these values since they should not influence our training in no form whatsoever.<br><span style="color:green; font-weight:bold">Proposed Solution:</span> Giving this reasoning, the normal choice here is to instantly drop these features. This will help to resolve conflicts later on.

# %%
# Dropping from Train and Validation.
X_train = X_train.drop(columns=["Agreement Reached","WCB Decision"])
X_val = X_val.drop(columns=["Agreement Reached","WCB Decision"])

# %% [markdown]
# We can also start by extracting and defining some date time variables for manuseability purposes:

# %%
#### Setting our variables to year for manuseability.
#Assembly Date
X_train["Assembly Date"] = pd.to_datetime(X_train["Assembly Date"])
X_val["Assembly Date"] = pd.to_datetime(X_val["Assembly Date"])
test["Assembly Date"] = pd.to_datetime(test["Assembly Date"])

# # C-2 Date
X_train["C-2 Date"] = pd.to_datetime(X_train["C-2 Date"])
X_val["C-2 Date"] = pd.to_datetime(X_val["C-2 Date"])
test["C-2 Date"] = pd.to_datetime(test["C-2 Date"])

# # C-3 Date
X_train["C-3 Date"] = pd.to_datetime(X_train["C-3 Date"])
X_val["C-3 Date"] = pd.to_datetime(X_val["C-3 Date"])
test["C-3 Date"] = pd.to_datetime(test["C-3 Date"])


X_train["Assembly Date"] = X_train["Assembly Date"].dt.year
X_val["Assembly Date"] = X_val["Assembly Date"].dt.year
test["Assembly Date"] = test["Assembly Date"].dt.year

X_train["C-2 Date"] = X_train["C-2 Date"].dt.year
X_val["C-2 Date"] = X_val["C-2 Date"].dt.year
test["C-2 Date"] = test["C-2 Date"].dt.year

X_train["C-3 Date"] = X_train["C-3 Date"].dt.year
X_val["C-3 Date"] = X_val["C-3 Date"].dt.year
test["C-3 Date"] = test["C-3 Date"].dt.year

# %% [markdown]
#  <a class="anchor" id="missing">
#
# ## 3.2 Adressing Missing Values
#
# </a>

# %% [markdown]
# Now that the logical incoherences have been solved, we can start looking at treating missing values.

# %%
print(X_train.isna().sum())
# Out:
# Accident Date                          2766
# Age at Injury                             0
# Alternative Dispute Resolution            0
# Assembly Date                             0
# Attorney/Representative                   0
# Average Weekly Wage                   21535
# Birth Year                            21745
# C-2 Date                              10926
# C-3 Date                             290385
# Carrier Name                              0
# Carrier Type                              0
# Claim Identifier                          0
# County of Injury                          0
# COVID-19 Indicator                        0
# District Name                             0
# First Hearing Date                   317502
# Gender                                    0
# IME-4 Count                          330921
# Industry Code                          7490
# Industry Code Description              7490
# Medical Fee Region                        0
# WCIO Cause of Injury Code             11741
# WCIO Cause of Injury Description      11741
# WCIO Nature of Injury Code            11756
# WCIO Nature of Injury Description     11756
# WCIO Part Of Body Code                12771
# WCIO Part Of Body Description         12771
# Zip Code                              21400
# Number of Dependents                      0
# dtype: int64

# %% [markdown]
# #### Accident Date

# %% [markdown]
# A particular and logical imputation for some missing values for Accident Date is computing it by summing the birth year with the Age at Injury!

# %%
# Train
X_train["Accident Date"] = pd.to_datetime(X_train["Accident Date"])
X_val["Accident Date"] = pd.to_datetime(X_val["Accident Date"])
# Val
X_train["Accident Date"] = X_train["Accident Date"].dt.year
X_val["Accident Date"] = X_val["Accident Date"].dt.year
# Test
test["Accident Date"] = pd.to_datetime(test["Accident Date"])
test["Accident Date"] = test["Accident Date"].dt.year

# %%
# Setting Birth Year as year as well
# Train
X_train["Birth Year"] = pd.to_datetime(X_train["Birth Year"])
X_val["Birth Year"] = pd.to_datetime(X_val["Birth Year"])
# Val
X_train["Birth Year"] = X_train["Birth Year"].dt.year
X_val["Birth Year"] = X_val["Birth Year"].dt.year
# Test
test["Birth Year"] = pd.to_datetime(test["Birth Year"])
test["Birth Year"] = test["Birth Year"].dt.year

# %%
# Filling the missing values with oru logical reasoning.
X_train["Accident Date"] = X_train["Accident Date"].fillna(X_train["Birth Year"] + X_train["Age at Injury"])
X_val["Accident Date"] = X_val["Accident Date"].fillna(X_val["Birth Year"] + X_val["Age at Injury"])

# Test
test["Accident Date"] = test["Accident Date"].fillna(test["Birth Year"] + test["Age at Injury"])

# %% [markdown]
# Accident Date missing values dropped from 2336  to 111. <span style="color:orange; font-weight:bold">Remaining missing values will be computed by KNNImputer as fallback</span>

# %% [markdown]
# #### Birth Year

# %%
# Same logic is applied here, but inversed!
X_train["Birth Year"] = X_train["Birth Year"].fillna(X_train["Accident Date"] - X_train["Age at Injury"])
X_val["Birth Year"] = X_val["Birth Year"].fillna(X_val["Accident Date"] - X_val["Age at Injury"])

# Test
test["Birth Year"] = test["Birth Year"].fillna(test["Accident Date"] - test["Age at Injury"])

# %% [markdown]
# Birth Year missing values dropped from 19721  to 111 same as accident date since it depends from its values. <span style="color:orange; font-weight:bold">Remaining missing values will be computed by KNNImputer as fallback</span>

# %% [markdown]
# #### Age at Injury

# %% [markdown]
# Feature age at injury doesn't include any NAN values. However, it includes values equal 0 which doesn't make a sense that's why we decided to replace the 0 values to NaN

# %%
# Replacing:
X_train["Age at Injury"] = X_train["Age at Injury"].replace(0,np.nan)

X_val["Age at Injury"] = X_val["Age at Injury"].replace(0,np.nan)

test["Age at Injury"] = test["Age at Injury"].replace(0,np.nan)

# %% [markdown]
# Following previous logical assumptions:
# - (-Age at Injury) = Birth Year - Accident Date
# - Which equals: Age at Injury = Birth Year - Accident Date
# - We can compute absolute value of this calculation.

# %%
X_train["Age at Injury"] = X_train["Age at Injury"].fillna(abs(X_train["Birth Year"] - X_train["Accident Date"]))

X_val["Age at Injury"] = X_val["Age at Injury"].fillna(abs(X_val["Birth Year"] - X_val["Accident Date"]))

test["Age at Injury"] = test["Age at Injury"].fillna(abs(test["Birth Year"] - test["Accident Date"]))

# %% [markdown]
# Age at Injury missing values dropped to 111 same as accident date since it depends from its values. <span style="color:orange; font-weight:bold">Remaining missing values will be computed by KNNImputer as fallback</span>

# %% [markdown]
# So basically we will use the KNN Imputer for remaining missing variables in Age at Injury, Birth Year, Accident Date

# %% [markdown]
# #### Average Weekly Wage

# %% [markdown]
# This varaiable includes in training dataset 19523 missing values, we decided to deal with the missing values through categorising the wages as follow
# * if wage is unknown (which is a nan value) -> the wage will be assigned category 0
# * if wage is between 0 and 500 -> the wage will be assigned category 1
# * if wage is between 500 and 1000 -> the wage will be assigned category 2
# * if wage is between 1000 and 1500 -> the wage will be assigned category 3
# * if wage is between 1500 and 2000 -> the wage will be assigned category 4
# * if wage is more than 2000 -> the wage will be assigned category 5

# %%
X_train["Average Weekly Wage"] = X_train["Average Weekly Wage"].replace(0,np.nan)

X_val["Average Weekly Wage"] = X_val["Average Weekly Wage"].replace(0,np.nan)

test["Average Weekly Wage"] = test["Average Weekly Wage"].replace(0,np.nan)

# %%
X_train["Average Weekly Wage"] = X_train["Average Weekly Wage"].fillna("Unknown")

X_val["Average Weekly Wage"] = X_val["Average Weekly Wage"].fillna("Unknown")

test["Average Weekly Wage"] = test["Average Weekly Wage"].fillna("Unknown")

# %%
def avwg(wage):
    if wage == "Unknown":
        return 0
    elif wage >= 0 and wage <= 500:
        return 1
    elif wage > 500 and wage <= 1000:
        return 2
    elif wage > 1000 and wage <= 1500:
        return 3
    elif wage > 1500 and wage <= 2000:
        return 4
    else:
        return 5
    
X_train["Average Weekly Wage"] = X_train["Average Weekly Wage"].apply(avwg)

X_val["Average Weekly Wage"] = X_val["Average Weekly Wage"].apply(avwg)

test["Average Weekly Wage"] = test["Average Weekly Wage"].apply(avwg)

# %% [markdown]
# The number of missing values dropped from 19523 to 0.

# %% [markdown]
# #### IME-4 Count

# %% [markdown]
# This varaiable includes in training dataset 316318 missing values, we decided to deal with the missing values through categorising the wages as follow
# * if IME is unknown (which is a nan value) -> the IME will be assigned category 0
# * if IME is 1 -> the IME will be assigned category 1
# * if IME is 2 -> the IME will be assigned category 2
# * if IME is 3 -> the IME will be assigned category 3
# * if IME is 4 -> the IME will be assigned category 4
# * if IME is 5 -> the IME will be assigned category 5
# * if IME is 6 -> the IME will be assigned category 6
# * if IME is 7 -> the IME will be assigned category 7
# * if IME is something else than these (8+) -> the IME will be assigned category 8

# %%
X_train["IME-4 Count"] = X_train["IME-4 Count"].replace(0,np.nan)

X_val["IME-4 Count"] = X_val["IME-4 Count"].replace(0,np.nan)

test["IME-4 Count"] = test["IME-4 Count"].replace(0,np.nan)

# %%
X_train["IME-4 Count"] = X_train["IME-4 Count"].fillna("Unknown")

X_val["IME-4 Count"] = X_val["IME-4 Count"].fillna("Unknown")

test["IME-4 Count"] = test["IME-4 Count"].fillna("Unknown")

# %%
def agg_ime(ime):
    if ime == "Unknown":
        return 0 
    elif ime == 1:
        return 1
    elif ime == 2:
        return 2
    elif ime == 3:
        return 3
    elif ime == 4:
        return 4
    elif ime == 5:
        return 5
    elif ime == 6:
        return 6
    elif ime == 7:
        return 7
    else:
        return 8
    
X_train["IME-4 Count"] = X_train["IME-4 Count"].apply(agg_ime)

X_val["IME-4 Count"] = X_val["IME-4 Count"].apply(agg_ime)

test["IME-4 Count"] = test["IME-4 Count"].apply(agg_ime)

# %% [markdown]
# #### First Hearing Date

# %% [markdown]
# As we know, values that are missing actually hold a true meaning, we will keep it that way!

# %%
X_train["First Hearing Date"] = pd.to_datetime(X_train["First Hearing Date"])
X_val["First Hearing Date"] = pd.to_datetime(X_val["First Hearing Date"])
test["First Hearing Date"] = pd.to_datetime(test["First Hearing Date"])

X_train["First Hearing Date"] = X_train["First Hearing Date"].dt.year
X_val["First Hearing Date"] = X_val["First Hearing Date"].dt.year
test["First Hearing Date"] = test["First Hearing Date"].dt.year

# %%
X_train["First Hearing Date"] = X_train["First Hearing Date"].fillna("Unknown")

X_val["First Hearing Date"] = X_val["First Hearing Date"].fillna("Unknown")

test["First Hearing Date"] = test["First Hearing Date"].fillna("Unknown")

# %%
def agg_fhd(fhd):
    if fhd != "Unknown":
        return 0
    else:
        return 1

X_train["First Hearing Date"] = X_train["First Hearing Date"].apply(agg_fhd)

X_val["First Hearing Date"] = X_val["First Hearing Date"].apply(agg_fhd)

test["First Hearing Date"] = test["First Hearing Date"].apply(agg_fhd)

# %% [markdown]
# #### Gender

# %% [markdown]
# Overall objective here was to reduce noise as much as possible. We feel that its best to capture these "outliers" as a whole.

# %%
X_train["Gender"] = X_train["Gender"].replace({"U": "Other", "X": "Other"})

X_val["Gender"] = X_val["Gender"].replace({"U": "Other", "X": "Other"})

test["Gender"] = test["Gender"].replace({"U": "Other", "X": "Other"})

# %% [markdown]
# #### District Name & Attorney/Representative & Covid-19 Indicator & Medical Fee Region

# %% [markdown]
# We will leave this variable as is, and later on encode it!

# %% [markdown]
# #### Alternative Dispute Resolution

# %% [markdown]
# Our "U" values are so residual it accounts for almost nothing, we will replace these with majority values proportionally.

# %%
# Reducing the noise by replacing with most common value:
X_train["Alternative Dispute Resolution"] = X_train["Alternative Dispute Resolution"].replace({"U":"N"})

X_val["Alternative Dispute Resolution"] = X_val["Alternative Dispute Resolution"].replace({"U":"N"})

test["Alternative Dispute Resolution"] = test["Alternative Dispute Resolution"].replace({"U":"N"})

# %% [markdown]
# #### County of Injury

# %% [markdown]
# As per our EDA, we noticed that we truly have many variables in this feature, and we are trying to capture the overall patterns and trends for our model to respond well.
# - We have ~50 differente counties, which is a lot. We could perhaps keep the 20 most frequent counties which account for most values, and aggregate the others into a separate category.

# %%
top_20_counties = X_train["County of Injury"].value_counts().nlargest(20).index.tolist()


# Training
X_train["County of Injury"] = X_train["County of Injury"].apply(lambda x: x if x in top_20_counties else "Other")

# Validation
X_val["County of Injury"] = X_val["County of Injury"].apply(lambda x: x if x in top_20_counties else "Other")

# Test
test["County of Injury"] = test["County of Injury"].apply(lambda x: x if x in top_20_counties else "Other")

# %% [markdown]
# #### Carrier Type

# %% [markdown]
# Once more as seen in the EDA, these variables that are being replaced were very residual, so we put them all in one basket to reduce the noise!

# %%
X_train["Carrier Type"] = X_train["Carrier Type"].replace({"UNKNOWN": "5D. SPECIAL FUND - UNKNOWN", "5C. SPECIAL FUND - POI CARRIER WCB MENANDS": "5D. SPECIAL FUND - UNKNOWN", "5A. SPECIAL FUND - CONS. COMM. (SECT. 25-A)": "5D. SPECIAL FUND - UNKNOWN"})

X_val["Carrier Type"] = X_val["Carrier Type"].replace({"UNKNOWN": "5D. SPECIAL FUND - UNKNOWN", "5C. SPECIAL FUND - POI CARRIER WCB MENANDS": "5D. SPECIAL FUND - UNKNOWN", "5A. SPECIAL FUND - CONS. COMM. (SECT. 25-A)": "5D. SPECIAL FUND - UNKNOWN"})

test["Carrier Type"] = test["Carrier Type"].replace({"UNKNOWN": "5D. SPECIAL FUND - UNKNOWN", "5C. SPECIAL FUND - POI CARRIER WCB MENANDS": "5D. SPECIAL FUND - UNKNOWN", "5A. SPECIAL FUND - CONS. COMM. (SECT. 25-A)": "5D. SPECIAL FUND - UNKNOWN"})

# %% [markdown]
# #### Carrier Name

# %% [markdown]
# Here we have around 2K different unique values, this is far too much for our model to capture the nuances and we must aggregate this further. The same logic as County of Injury was followed!

# %%
# Finding the top 50 carriers based on the training set only!!
top_50_carriers = X_train["Carrier Name"].value_counts().nlargest(50).index.tolist()

# Training 
X_train["Carrier Name"] = X_train["Carrier Name"].apply(lambda x: x if x in top_50_carriers else "Other")

# Validation 
X_val["Carrier Name"] = X_val["Carrier Name"].apply(lambda x: x if x in top_50_carriers else "Other")

# Test 
test["Carrier Name"] = test["Carrier Name"].apply(lambda x: x if x in top_50_carriers else "Other")

# %% [markdown]
# #### C-2 Date

# %% [markdown]
# We will aggregate this variable to try and reduce the noise. Encoding will be elaborated later on.
# - It's important to note that, when defining our function for aggregation, we must keep in mind that our test set holds different date values, and we must fit this accordingly.

# %%
# Replacing "nans" with "Unknown" across all datasets!
X_train["C-2 Date"] = X_train["C-2 Date"].replace(np.nan, "Unknown")
X_val["C-2 Date"] = X_val["C-2 Date"].replace(np.nan, "Unknown")
test["C-2 Date"] = test["C-2 Date"].replace(np.nan, "Unknown")

# %%
# Defining a single aggregation function that handles all expected cases...
def agg_c2_date(year):
    if year == 2023:
        return 0
    elif year == 2022:
        return 1
    elif year == 2021:
        return 2
    elif year == 2020:
        return 3
    elif year == "Unknown":
        return 4
    elif year == 2024:  # This is for our test set
        return 5
    else:
        return 6

# %%
# Train
X_train["C-2 Date"] = X_train["C-2 Date"].apply(agg_c2_date)
# Validation
X_val["C-2 Date"] = X_val["C-2 Date"].apply(agg_c2_date)
# Test
test["C-2 Date"] = test["C-2 Date"].apply(agg_c2_date)

# %% [markdown]
# #### C-3 Date

# %% [markdown]
# Our C-3 Date, will follow the same logic as C-2 Date!

# %%
X_train["C-3 Date"] = X_train["C-3 Date"].replace(np.nan, "Unknown")
X_val["C-3 Date"] = X_val["C-3 Date"].replace(np.nan, "Unknown")
test["C-3 Date"] = test["C-3 Date"].replace(np.nan, "Unknown")

# %%
# Applying the Aggregation to our variables.
X_train["C-3 Date"] = X_train["C-3 Date"].apply(agg_c2_date)
X_val["C-3 Date"] = X_val["C-3 Date"].apply(agg_c2_date)
test["C-3 Date"] = test["C-3 Date"].apply(agg_c2_date)

# %% [markdown]
# #### Zip Code

# %% [markdown]
# We will create a new variable here, which will be a direct derivation from the Zip Code, subsequently we will drop this feature entirely since a derivation from this one will become totally redudant with our current feature.

# %% [markdown]
# #### For the below variables we filled the missing values with the mode, but the mode that was defined in our trai set! This was done because when we must "see" directly information on validation and test to train our model.

# %% [markdown]
# #### Industry Code and Description

# %%
# Calculating the mode for Industry Code and Industry Code Description in the training set
industry_code_mode = X_train["Industry Code"].mode()[0]
industry_code_description_mode = X_train["Industry Code Description"].mode()[0]

# %%
# Training
X_train["Industry Code"] = X_train["Industry Code"].replace(np.nan, industry_code_mode)
X_train["Industry Code Description"] = X_train["Industry Code Description"].replace(np.nan, industry_code_description_mode)

# Validation
X_val["Industry Code"] = X_val["Industry Code"].replace(np.nan, industry_code_mode)
X_val["Industry Code Description"] = X_val["Industry Code Description"].replace(np.nan, industry_code_description_mode)

# Test
test["Industry Code"] = test["Industry Code"].replace(np.nan, industry_code_mode)
test["Industry Code Description"] = test["Industry Code Description"].replace(np.nan, industry_code_description_mode)

# %% [markdown]
# #### WCIO Cause of Injury Code & Description

# %%
cause_injury_code_mode = X_train["WCIO Cause of Injury Code"].mode()[0]
cause_injury_description_mode = X_train["WCIO Cause of Injury Description"].mode()[0]

# %%
# Train set:
X_train["WCIO Cause of Injury Code"] = X_train["WCIO Cause of Injury Code"].replace(np.nan, cause_injury_code_mode)
X_train["WCIO Cause of Injury Description"] = X_train["WCIO Cause of Injury Description"].replace(np.nan, cause_injury_description_mode)

# Validation set
X_val["WCIO Cause of Injury Code"] = X_val["WCIO Cause of Injury Code"].replace(np.nan, cause_injury_code_mode)
X_val["WCIO Cause of Injury Description"] = X_val["WCIO Cause of Injury Description"].replace(np.nan, cause_injury_description_mode)

# Test set
test["WCIO Cause of Injury Code"] = test["WCIO Cause of Injury Code"].replace(np.nan, cause_injury_code_mode)
test["WCIO Cause of Injury Description"] = test["WCIO Cause of Injury Description"].replace(np.nan, cause_injury_description_mode)

# %% [markdown]
# #### WCIO Natury of Injury Code & Description

# %%
nature_injury_code_mode = X_train["WCIO Nature of Injury Code"].mode()[0]
nature_injury_description_mode = X_train["WCIO Nature of Injury Description"].mode()[0]

# %%
# Train set:
X_train["WCIO Nature of Injury Code"] = X_train["WCIO Nature of Injury Code"].replace(np.nan, nature_injury_code_mode)
X_train["WCIO Nature of Injury Description"] = X_train["WCIO Nature of Injury Description"].replace(np.nan, nature_injury_description_mode)

# Validation set
X_val["WCIO Nature of Injury Code"] = X_val["WCIO Nature of Injury Code"].replace(np.nan, nature_injury_code_mode)
X_val["WCIO Nature of Injury Description"] = X_val["WCIO Nature of Injury Description"].replace(np.nan, nature_injury_description_mode)

# Test set
test["WCIO Nature of Injury Code"] = test["WCIO Nature of Injury Code"].replace(np.nan, nature_injury_code_mode)
test["WCIO Nature of Injury Description"] = test["WCIO Nature of Injury Description"].replace(np.nan, nature_injury_description_mode)

# %% [markdown]
# #### WCIO Part of Body Description

# %%
part_body_code_mode = X_train["WCIO Part Of Body Code"].mode()[0]
part_body_description_mode = X_train["WCIO Part Of Body Description"].mode()[0]

# %%
# Train set
X_train["WCIO Part Of Body Code"] = X_train["WCIO Part Of Body Code"].replace(np.nan, part_body_code_mode)
X_train["WCIO Part Of Body Description"] = X_train["WCIO Part Of Body Description"].replace(np.nan, part_body_description_mode)

# Validation set
X_val["WCIO Part Of Body Code"] = X_val["WCIO Part Of Body Code"].replace(np.nan, part_body_code_mode)
X_val["WCIO Part Of Body Description"] = X_val["WCIO Part Of Body Description"].replace(np.nan, part_body_description_mode)

# Test set
test["WCIO Part Of Body Code"] = test["WCIO Part Of Body Code"].replace(np.nan, part_body_code_mode)
test["WCIO Part Of Body Description"] = test["WCIO Part Of Body Description"].replace(np.nan, part_body_description_mode)

# %%
X_train.isna().sum()
# Out:
# Accident Date                          123
# Age at Injury                          123
# Alternative Dispute Resolution           0
# Assembly Date                            0
# Attorney/Representative                  0
# Average Weekly Wage                      0
# Birth Year                             123
# C-2 Date                                 0
# C-3 Date                                 0
# Carrier Name                             0
# Carrier Type                             0
# Claim Identifier                         0
# County of Injury                         0
# COVID-19 Indicator                       0
# District Name                            0
# First Hearing Date                       0
# Gender                                   0
# IME-4 Count                              0
# Industry Code                            0
# Industry Code Description                0
# Medical Fee Region                       0
# WCIO Cause of Injury Code                0
# WCIO Cause of Injury Description         0
# WCIO Nature of Injury Code               0
# WCIO Nature of Injury Description        0
# WCIO Part Of Body Code                   0
# WCIO Part Of Body Description            0
# Zip Code                             21400
# Number of Dependents                     0
# dtype: int64

# %% [markdown]
#  <a class="anchor" id="feature">
#
# ## 3.3 Feature Engineering
#
# </a>

# %% [markdown]
# Feature Engineering is a must for projects in ML and DM fields. Usually it enables us to capture more insightful trends and patterns for our models, either by transformations, aggregations, or derivations of sorts.

# %% [markdown]
# ##### COVID-19 per Industry Interaction

# %% [markdown]
# We know from historical data that COVID-19 had more of an impact in certain industries that perhaps were more affected by this pandemic. By creating an interaction variable, we can perhaps get more interesting insights, by aggregating these two we can perhaps drop the other two singular features, which become redundant with the creation of this interaction. So in a way we combine information, creating a new variable, allowing us to drop 2 features.
# - We will check whether to drop or not in feature selection section!

# %%
X_train.groupby("COVID-19 Indicator")["Industry Code"].value_counts()
# Out:
# COVID-19 Indicator  Industry Code
# N                   62.0             84966
#                     92.0             63451
#                     61.0             32814
#                     44.0             30879
#                     48.0             27300
#                     23.0             23059
#                     72.0             19552
#                     56.0             15463
#                     45.0             13424
#                     33.0             12924
#                     42.0             11356
#                     49.0             10997
#                     81.0              9663
#                     32.0              8062
#                     31.0              7555
#                     71.0              7291
#                     54.0              7141
#                     51.0              6761
#                     53.0              6596
#                     52.0              5812
#                     22.0              2206
#                     11.0              1796
#                     21.0               507
#                     55.0               268
# Y                   62.0              8172
#                     92.0              5614
#                     44.0              1805
#                     49.0              1523
#                     48.0               743
#                     61.0               478
#                     56.0               419
#                     52.0               340
#                     72.0               331
#                     81.0               252
#                     71.0               186
#                     45.0               145
#                     54.0               108
#                     53.0                98
#                     33.0                97
#                     32.0                83
#                     42.0                78
#                     51.0                72
#                     23.0                67
#                     31.0                50
#                     22.0                10
#                     55.0                 3
#                     21.0                 2
# Name: count, dtype: int64

# %%
X_train['COVID_Industry'] = X_train['COVID-19 Indicator'].astype(str) + ":" + X_train['Industry Code'].astype(str)

X_val['COVID_Industry'] = X_val['COVID-19 Indicator'].astype(str) + ":" + X_val['Industry Code'].astype(str)

test['COVID_Industry'] = test['COVID-19 Indicator'].astype(str) + ":" + test['Industry Code'].astype(str)

# %% [markdown]
# #### Zip Code

# %% [markdown]
# We feel like given the amount of Zip Code missing values, and also the information that is being shared by this feature, it could perhaps be more interesting to create a binary variable telling us whether we do or do not have a zip code for this particular claim.

# %%
def binary(zip):
    if pd.isna(zip):
        return 0
    else:
        return 1

# %%
X_train["Zip Code Binary"] = X_train["Zip Code"].apply(binary)

X_val["Zip Code Binary"] = X_val["Zip Code"].apply(binary)

test["Zip Code Binary"] = test["Zip Code"].apply(binary)

# %%
X_train = X_train.drop(columns="Zip Code")
X_val = X_val.drop(columns="Zip Code")

test = test.drop(columns="Zip Code")

# %% [markdown]
#  <a class="anchor" id="scaling">
#
# ## 3.4 KNN Imputation and Scaling
#
# </a>

# %% [markdown]
# As we know, we must scale our data before using KNN Imputation. This type of imputation is based on calculating distance metrics between points, therefore it is self explainable why we should keep things on a similar scale! For this we can use Robust Scaler.
# - Robust Scaler is also particularly useful when our data contains outliers, as it scales features based on the median and IQR range, which makes it less sensitive to extreme values compared to StandardScaler or MinMaxScaler. Therefore by computing RobustScaler we are dealing with both of these problems at once.
# - We do not want to reduce too much the size of our dataset, as usually more information means models will perform better (if the data set was treated accordingly of course). Therefore, we feel that this application is the best of both worlds.

# %% [markdown]
# Scaling:

# %%
# We start off by separating our numeric from our categorical features:
numeric_columns = X_train.select_dtypes(include=np.number).columns

# Remember: To avoid data leakage it's a must that we do not fit any methods on anything other than our train set. We fit on train and transform on the others!
scaler = RobustScaler() # We use the default parameters to center before scaling, and to scale based on IQR.

# We create copies for safety measures.
X_train_scaled = X_train.copy()
X_val_scaled = X_val.copy()
test_scaled = test.copy()

# We fit our numeric features on our train set (in this case we can already transform to apply it, for other we just transform):
X_train_scaled[numeric_columns] = scaler.fit_transform(X_train[numeric_columns])

# Val:
X_val_scaled[numeric_columns] = scaler.transform(X_val[numeric_columns])

# Test:
test_scaled[numeric_columns] = scaler.transform(test[numeric_columns])

# %% [markdown]
# KNN Imputer

# %% [markdown]
# KNN Imputer elaborates imputation for misssing values based on the distances between K closest data points. Distance is calculated by default using Euclidean Distance. It's important to note that we used default values, but by tuning these parameters we could obtain different results!
# - It's computed after scaling, which makes sense since its primary calculation is based on distance, its important to have everything on the same scale.

# %%
imputer = KNNImputer() # we will use the default values for now: 5 neighbors and uniform weight distribution. But we will adjust if needed.

# Once more: Only fit in train!
X_train_scaled[numeric_columns] = imputer.fit_transform(X_train_scaled[numeric_columns])

X_val_scaled[numeric_columns] = imputer.transform(X_val_scaled[numeric_columns])

test_scaled[numeric_columns] = imputer.transform(test_scaled[numeric_columns])

# %% [markdown]
# Only 21 seconds to run since we have few missing values. Time increases exponentially if we have a lot of missing values. Good to keep this in mind. It might be possible that given our model scores we try to do this for a few more variables.

# %% [markdown]
#  <a class="anchor" id="encoding">
#
# ## 3.5 Categorical Data Encoding
#
# </a>

# %% [markdown]
# We will use LabelEncoder and OrdinalEncoder seen in class. This fits our purpose of encoding our categorical columns. LabelEncoder is solely for our target variable, where as OrdinalEncoder will encode multiple categorical features. This is a necessary process for our model to be able to interpret our results. Having everything on a numerical scale is essencial.

# %%
categorical_features = X_train.select_dtypes(include=["object","category"]).columns
categorical_features
# Out:
# Index(['Alternative Dispute Resolution', 'Attorney/Representative',
#        'Carrier Name', 'Carrier Type', 'County of Injury',
#        'COVID-19 Indicator', 'District Name', 'Gender',
#        'Industry Code Description', 'Medical Fee Region',
#        'WCIO Cause of Injury Description', 'WCIO Nature of Injury Description',
#        'WCIO Part Of Body Description', 'COVID_Industry'],
#       dtype='object')

# %% [markdown]
# Note: When we try to run this the first time we get an error saying that there was a unknown category (in COVID_Industry Interaction) which the validation or test set has never seen before. To handle this OrdinalEncoder has a parameter handle_unknown='use_encoded_value', which lets us specifiy a specific value. We set it as special number so the model can recognize these occurences.

# %%
# We first select our categorical columns with exception of our target! Since we split this is already done.
# Note: We do not use scaled features since this is only for categorical.
categorical_features = X_train.select_dtypes(include=["object","category"]).columns

# We initialize our encoders:
ordinal_enc = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value= 99)
label_enc = LabelEncoder()

# We fit it to our train and apply it on the others:
X_train[categorical_features] = ordinal_enc.fit_transform(X_train[categorical_features])

X_val[categorical_features] = ordinal_enc.transform(X_val[categorical_features])

test[categorical_features] = ordinal_enc.transform(test[categorical_features])

# For our target:
# Train
y_train_encoded = label_enc.fit_transform(y_train)

# Val
y_val_encoded = label_enc.transform(y_val)

# %% [markdown]
# And now that scaling and encoding has been done seperately, we can combine our dataframes! To ensure we are ready for modelling stages:

# %%
# Combining the train scaled with our categorical features that were encoded and so on!
# For the training set
X_train_final = X_train_scaled.copy() 
X_train_final[categorical_features] = X_train[categorical_features]  # Add our encoded categorical features

# For the validation set
X_val_final = X_val_scaled.copy() 
X_val_final[categorical_features] = X_val[categorical_features]  # Add our encoded categorical features

# For the test set
test_final = test_scaled.copy()  
test_final[categorical_features] = test[categorical_features]  # Add our encoded categorical features

# %% [markdown]
#  <a class="anchor" id="featureselection">
#
# # 4. Feature Selection
#
# </a>

# %% [markdown]
#  <a class="anchor" id="filter">
#
# ## 4.1 Filter Methods
#
# </a>

# %% [markdown]
#  <a class="anchor" id="univariate">
#
# ### 4.1.1 Univariate Variables
#
# </a>

# %%
X_train_final.var()
# Out:
# Accident Date                          4.825624
# Age at Injury                          0.374310
# Alternative Dispute Resolution         0.004553
# Assembly Date                          0.164138
# Attorney/Representative                0.216257
# Average Weekly Wage                    0.595166
# Birth Year                            13.206397
# C-2 Date                               0.197414
# C-3 Date                               1.192055
# Carrier Name                         161.263751
# Carrier Type                           1.114103
# Claim Identifier                       0.334158
# County of Injury                      34.394206
# COVID-19 Indicator                     0.045719
# District Name                          3.524110
# First Hearing Date                     0.193601
# Gender                                 0.256337
# IME-4 Count                            2.682562
# Industry Code                          1.311935
# Industry Code Description             28.996774
# Medical Fee Region                     1.788830
# WCIO Cause of Injury Code              0.336472
# WCIO Cause of Injury Description     313.042565
# WCIO Nature of Injury Code             0.662532
# WCIO Nature of Injury Description    281.296180
# WCIO Part Of Body Code                 1.215331
# WCIO Part Of Body Description        179.783212
# Number of Dependents                   0.250119
# COVID_Industry                        72.976192
# Zip Code Binary                        0.047237
# dtype: float64

# %% [markdown]
#  <a class="anchor" id="correlation">
#
# ### 4.1.2 Correlation Indices
#
# </a>

# %%
# Define a function that will give us the heatmap with given parameters for our numerical variables
def cor_heatmap(cor):
    plt.figure(figsize=(25,20))
    sns.heatmap(data = cor, annot = True, cmap = plt.cm.Reds, fmt='.1')
    plt.show()

# %% [markdown]
# We are going to use Spearman's method since most of our variables are not normally distributed!

# %%
cor_spearman = X_train_final.corr(method ='spearman')
cor_heatmap(cor_spearman)

# %% [markdown]
# We see that we have a few correlated features that we might have to drop. We will keep track of these, and establish a brief summary in the end. Other techniques need to be used to be sure of what features to drop!
# - As an overview it seems that: Either Claim Identifier / Accident Date / Assembly Date will need to be dropped. And possibly Industry Code or Covid Industry

# %% [markdown]
#  <a class="anchor" id="wrapper">
#
# ## 4.2 Wrapper Methods
#
# </a>

# %% [markdown]
#  <a class="anchor" id="rfe">
#
# ### 4.2.1 RFE
#
# </a>

# %% [markdown]
# For the RFE we will first want to know what would be the optimal features to select:

# %% [markdown]
# We will run this cde, with steps and using a subsample since it is very expensive computationally

# %%
#no of features
nof_list=np.arange(1,30,5)            
high_score=0
#Variable to store the optimum features
nof=0           
train_score_list =[]
val_score_list = []

for n in range(len(nof_list)):
    model = LogisticRegression() # default parameters 
    
    rfe = RFE(estimator = model,n_features_to_select = nof_list[n])
    X_train_rfe = rfe.fit_transform(X_train_final[:50000] ,y_train_encoded[:50000])
    X_val_rfe = rfe.transform(X_val_final[:50000])
    model.fit(X_train_rfe,y_train_encoded[:50000])
    
    #storing results on training data
    train_score = model.score(X_train_rfe,y_train_encoded[:50000])
    train_score_list.append(train_score)
    
    #storing results on training data
    val_score = model.score(X_val_rfe,y_val_encoded[:50000])
    val_score_list.append(val_score)
    
    #check best score
    if(val_score >= high_score):
        high_score = val_score
        nof = nof_list[n]
print("Optimum number of features: %d" %nof)
print("Score with %d features: %f" % (nof, high_score))
# Out:
# Optimum number of features: 1
# Score with 1 features: 0.737940

# %% [markdown]
# This previous code prints the following: Optimal Features: 26
# - Score with 26 features: 0.7427.
# - We will comment it out for now since it takes 4 minutes to run.

# %% [markdown]
# Let's check which features RFE is dropping:

# %%
model = LogisticRegression()

rfe = RFE(estimator = model, n_features_to_select = 26)

X_rfe = rfe.fit_transform(X = X_train_final, y = y_train_encoded)
# Checking for selected features
selected_features = pd.Series(rfe.support_, index = X_train_final.columns)
selected_features
# Out:
# Accident Date                         True
# Age at Injury                         True
# Alternative Dispute Resolution       False
# Assembly Date                         True
# Attorney/Representative               True
# Average Weekly Wage                   True
# Birth Year                           False
# C-2 Date                              True
# C-3 Date                              True
# Carrier Name                          True
# Carrier Type                          True
# Claim Identifier                      True
# County of Injury                      True
# COVID-19 Indicator                    True
# District Name                         True
# First Hearing Date                    True
# Gender                                True
# IME-4 Count                           True
# Industry Code                         True
# Industry Code Description             True
# Medical Fee Region                    True
# WCIO Cause of Injury Code             True
# WCIO Cause of Injury Description      True
# WCIO Nature of Injury Code            True
# WCIO Nature of Injury Description     True
# WCIO Part Of Body Code                True
# WCIO Part Of Body Description         True
# Number of Dependents                 False
# COVID_Industry                        True
# Zip Code Binary                      False
# dtype: bool

# %% [markdown]
# It appears that ZIP Code Binary; Number of Dependents, Birth year and ADR is being dropped. We will once more keep this in mind.

# %% [markdown]
# As mentioned previously, we have tested this with Logistic Regression which altough it's suited for classification it may not be the best model for our purposes given the complexity of our dataset.

# %%
#no of features
nof_list=np.arange(1,30,5)            
high_score=0
#Variable to store the optimum features
nof=0           
train_score_list =[]
val_score_list = []

for n in range(len(nof_list)):
    model = RandomForestClassifier() # default parameters n_estimators=100, higher values may be slower
    
    rfe = RFE(estimator = model,n_features_to_select = nof_list[n])
    X_train_rfe = rfe.fit_transform(X_train_final[:50000] ,y_train_encoded[:50000])
    X_val_rfe = rfe.transform(X_val_final[:50000])
    model.fit(X_train_rfe,y_train_encoded[:50000])
    
    #storing results on training data
    train_score = model.score(X_train_rfe,y_train_encoded[:50000])
    train_score_list.append(train_score)
    
    #storing results on training data
    val_score = model.score(X_val_rfe,y_val_encoded[:50000])
    val_score_list.append(val_score)
    
    #check best score
    if(val_score >= high_score):
        high_score = val_score
        nof = nof_list[n]
print("Optimum number of features: %d" %nof)
print("Score with %d features: %f" % (nof, high_score))
# Out:
# Optimum number of features: 26
# Score with 26 features: 0.781840

# %% [markdown]
# This code prints 26 optimal features (same as previous one). And a score 0f ~0.79.
# - Runtime of 20 minutes so we will comment this one out as we already know what the output is!

# %% [markdown]
# Reminder: We are looking to find out what is best optimum features to keep on our model. The score we get is still not fully representative of what we want!

# %% [markdown]
#  <a class="anchor" id="embadded">
#
# ## 4.3 Embadded Methods
#
# </a>

# %% [markdown]
#  <a class="anchor" id="lasso">
#
# ### 4.3.1 LASSO
#
# </a>

# %%
regression = LassoCV()

regression.fit(X_train_final,y_train_encoded)

coef = pd.Series(regression.coef_, index = X_train_final.columns)
coef.sort_values()
# Out:
# C-2 Date                            -0.339741
# Assembly Date                       -0.267247
# First Hearing Date                  -0.191708
# Claim Identifier                    -0.122988
# WCIO Cause of Injury Code           -0.057662
# Medical Fee Region                  -0.044405
# WCIO Nature of Injury Code          -0.023317
# Carrier Type                        -0.014636
# Gender                              -0.013036
# COVID_Industry                      -0.006064
# Age at Injury                       -0.000765
# Number of Dependents                -0.000000
# COVID-19 Indicator                  -0.000000
# Alternative Dispute Resolution       0.000000
# Zip Code Binary                     -0.000000
# Industry Code Description            0.000116
# County of Injury                     0.000291
# Birth Year                           0.000292
# WCIO Nature of Injury Description    0.000336
# WCIO Part Of Body Description        0.000570
# WCIO Cause of Injury Description     0.000815
# Carrier Name                         0.001537
# District Name                        0.003230
# C-3 Date                             0.006863
# WCIO Part Of Body Code               0.009418
# Accident Date                        0.016986
# Industry Code                        0.025881
# IME-4 Count                          0.055999
# Attorney/Representative              0.503557
# Average Weekly Wage                  0.848486
# dtype: float64

# %% [markdown]
# Variables to eliminate as per Lasso regression: COVID-19 Indicator; Number of Dependents; Zip Code Binary

# %% [markdown]
# ### FINAL INSIGHTS:

# %% [markdown]
# <hr>
#
# | Predictor | Spearman | RFE LR| RFE RFC | Lasso | What to do? |
# | --- | --- | --- | --- |--- |---|
# | COVID-19 Indicator | Keep | Keep | Keep |Remove | Include in the model |
# | Number of Dependents | Keep | Remove | Remove |Remove| Discard |
# | Zip Code Binary | Keep | Remove | Remove | Remove | Discard |
# | Birth Year | Keep | Remove | Remove | Keep | Discard  |
# | Alternative Dispute Resolution | Keep | Remove | Remove | Keep | Try with and without |
# | Claim Identifier | Remove | Keep | Keep | Keep | Include in the model |
# | Industry Code | Remove  |Keep |Keep | Keep |  Include |
#
#
# <hr>

# %% [markdown]
# From Lasso and RFE there are two in which we are certain we can remove: Number of Dependents and Zip Code Binary.

# %% [markdown]
# Then, I believe we can try and remove COVID-19 Indicator, since that information is already in COVID_Industry.

# %% [markdown]
# For the final feature to remove, we should probably remove one of Claim Identifier, Accident Date or Assembly Date. Since they are very highly correlated in Spearman's method.
# - We can start off by removing Accident Date, and this might come down to trial and error based on what the model gives us.

# %% [markdown]
#  <a class="anchor" id="model">
#
# # 5. Model Assessment
#
# </a>

# %%
X_train_final = X_train_final.drop(columns=["Number of Dependents", "Zip Code Binary", "COVID-19 Indicator", "County of Injury"])

X_val_final = X_val_final.drop(columns=["Number of Dependents", "Zip Code Binary", "COVID-19 Indicator", "County of Injury"])

test_final = test_final.drop(columns=["Number of Dependents", "Zip Code Binary", "COVID-19 Indicator", "County of Injury"])

# %%
def fit_model(model,X_train_final, y_train_encoded, X_val_final, y_val_encoded):
     model.fit(X_train_final, y_train_encoded)
     y_pred = model.predict(X_val_final)
     print('F1 score: {}'.format(f1_score(y_val_encoded, y_pred, average="macro")))
     return model

# %%
# logistic regression
log = LogisticRegression(random_state=42, max_iter=1000)
log = fit_model(log, X_train_final, y_train_encoded, X_val_final, y_val_encoded)
# Out:
# F1 score: 0.32085687045549327

# %%
rf = RandomForestClassifier(random_state=42)
rf = fit_model(rf, X_train_final, y_train_encoded, X_val_final, y_val_encoded)
# Out:
# F1 score: 0.4075997860576208

# %%
gb = GradientBoostingClassifier()
gb = fit_model(gb, X_train_final, y_train_encoded, X_val_final, y_val_encoded)
# Out:
# F1 score: 0.39688464722098415

# %%
dt = DecisionTreeClassifier()
dt = fit_model(dt,X_train_final,y_train_encoded,X_val_final, y_val_encoded)
# Out:
# F1 score: 0.3843935008635754

# %%
cat = CatBoostClassifier()
cat = fit_model(cat, X_train_final,y_train_encoded,X_val_final,y_val_encoded)
# Out:
# Learning rate set to 0.107809
# 0:	learn: 1.6667515	total: 1.45s	remaining: 24m 10s
# 1:	learn: 1.4559000	total: 2.26s	remaining: 18m 49s
# 2:	learn: 1.3117210	total: 2.66s	remaining: 14m 42s
# 3:	learn: 1.2063927	total: 3.23s	remaining: 13m 23s
# 4:	learn: 1.1227318	total: 3.62s	remaining: 12m 1s
# 5:	learn: 1.0567576	total: 4.31s	remaining: 11m 54s
# 6:	learn: 1.0001778	total: 4.69s	remaining: 11m 5s
# 7:	learn: 0.9544782	total: 5.03s	remaining: 10m 24s
# 8:	learn: 0.9145188	total: 5.43s	remaining: 9m 58s
# 9:	learn: 0.8807730	total: 5.78s	remaining: 9m 32s
# 10:	learn: 0.8515293	total: 6.11s	remaining: 9m 9s
# 11:	learn: 0.8268995	total: 6.51s	remaining: 8m 56s
# 12:	learn: 0.8057267	total: 7s	remaining: 8m 51s
# 13:	learn: 0.7868867	total: 7.4s	remaining: 8m 41s
# 14:	learn: 0.7699426	total: 7.77s	remaining: 8m 30s
# 15:	learn: 0.7553558	total: 8.09s	remaining: 8m 17s
# 16:	learn: 0.7419783	total: 8.45s	remaining: 8m 8s
# 17:	learn: 0.7300878	total: 8.78s	remaining: 7m 58s
# 18:	learn: 0.7200818	total: 9.13s	remaining: 7m 51s
# 19:	learn: 0.7114405	total: 9.54s	remaining: 7m 47s
# 20:	learn: 0.7035304	total: 9.9s	remaining: 7m 41s
# 21:	learn: 0.6960335	total: 10.3s	remaining: 7m 39s
# 113:	learn: 0.5944286	total: 43.9s	remaining: 5m 41s
# 114:	learn: 0.5939579	total: 44.3s	remaining: 5m 40s
# 115:	learn: 0.5936474	total: 44.6s	remaining: 5m 40s
# 116:	learn: 0.5934916	total: 45s	remaining: 5m 39s
# 117:	learn: 0.5933699	total: 45.3s	remaining: 5m 38s
# 118:	learn: 0.5931541	total: 45.7s	remaining: 5m 38s
# 119:	learn: 0.5929158	total: 46.1s	remaining: 5m 38s
# 120:	learn: 0.5926366	total: 46.5s	remaining: 5m 37s
# 121:	learn: 0.5925212	total: 46.8s	remaining: 5m 36s
# 122:	learn: 0.5923937	total: 47.1s	remaining: 5m 35s
# 123:	learn: 0.5922165	total: 47.4s	remaining: 5m 34s
# 124:	learn: 0.5919974	total: 47.8s	remaining: 5m 34s
# 125:	learn: 0.5918110	total: 48.1s	remaining: 5m 33s
# 126:	learn: 0.5916905	total: 48.4s	remaining: 5m 32s
# 127:	learn: 0.5915384	total: 48.8s	remaining: 5m 32s
# 128:	learn: 0.5913653	total: 49.1s	remaining: 5m 31s
# 129:	learn: 0.5911522	total: 49.5s	remaining: 5m 30s
# 130:	learn: 0.5908680	total: 49.8s	remaining: 5m 30s
# 131:	learn: 0.5907216	total: 50.2s	remaining: 5m 29s
# 132:	learn: 0.5904175	total: 50.6s	remaining: 5m 29s
# 133:	learn: 0.5901973	total: 51s	remaining: 5m 29s
# 134:	learn: 0.5900055	total: 51.4s	remaining: 5m 29s
# 135:	learn: 0.5897078	total: 51.7s	remaining: 5m 28s
# 136:	learn: 0.5893627	total: 52.1s	remaining: 5m 28s
# 137:	learn: 0.5891944	total: 52.4s	remaining: 5m 27s
# 138:	learn: 0.5890232	total: 52.7s	remaining: 5m 26s
# 139:	learn: 0.5888708	total: 53s	remaining: 5m 25s
# 140:	learn: 0.5887350	total: 53.3s	remaining: 5m 24s
# 141:	learn: 0.5884743	total: 53.6s	remaining: 5m 23s
# 142:	learn: 0.5882758	total: 53.9s	remaining: 5m 23s
# 143:	learn: 0.5879601	total: 54.3s	remaining: 5m 22s
# 144:	learn: 0.5878660	total: 54.6s	remaining: 5m 21s
# 145:	learn: 0.5877547	total: 54.9s	remaining: 5m 20s
# 146:	learn: 0.5875462	total: 55.4s	remaining: 5m 21s
# 147:	learn: 0.5873106	total: 55.7s	remaining: 5m 20s
# 148:	learn: 0.5871446	total: 56.2s	remaining: 5m 20s
# 149:	learn: 0.5869995	total: 56.5s	remaining: 5m 20s
# 150:	learn: 0.5868474	total: 57s	remaining: 5m 20s
# 151:	learn: 0.5867026	total: 57.4s	remaining: 5m 20s
# 152:	learn: 0.5865890	total: 57.7s	remaining: 5m 19s
# 153:	learn: 0.5864200	total: 58.1s	remaining: 5m 19s
# 154:	learn: 0.5863051	total: 58.4s	remaining: 5m 18s
# 155:	learn: 0.5861053	total: 58.8s	remaining: 5m 17s
# 156:	learn: 0.5859642	total: 59.1s	remaining: 5m 17s
# 157:	learn: 0.5857554	total: 59.4s	remaining: 5m 16s
# 158:	learn: 0.5854904	total: 59.9s	remaining: 5m 16s
# 159:	learn: 0.5853218	total: 1m	remaining: 5m 16s
# 160:	learn: 0.5852148	total: 1m	remaining: 5m 15s
# 161:	learn: 0.5850469	total: 1m	remaining: 5m 15s
# 162:	learn: 0.5848887	total: 1m 1s	remaining: 5m 15s
# 163:	learn: 0.5846785	total: 1m 1s	remaining: 5m 14s
# 164:	learn: 0.5845870	total: 1m 1s	remaining: 5m 13s
# 165:	learn: 0.5843750	total: 1m 2s	remaining: 5m 13s
# 166:	learn: 0.5842678	total: 1m 2s	remaining: 5m 12s
# 167:	learn: 0.5840652	total: 1m 2s	remaining: 5m 11s
# 168:	learn: 0.5838126	total: 1m 3s	remaining: 5m 11s
# 169:	learn: 0.5836282	total: 1m 3s	remaining: 5m 10s
# 170:	learn: 0.5834894	total: 1m 3s	remaining: 5m 9s
# 171:	learn: 0.5832790	total: 1m 4s	remaining: 5m 9s
# 172:	learn: 0.5830853	total: 1m 4s	remaining: 5m 8s
# 173:	learn: 0.5829350	total: 1m 4s	remaining: 5m 7s
# 174:	learn: 0.5827022	total: 1m 5s	remaining: 5m 7s
# 175:	learn: 0.5825402	total: 1m 5s	remaining: 5m 6s
# 176:	learn: 0.5823449	total: 1m 5s	remaining: 5m 6s
# 177:	learn: 0.5822000	total: 1m 6s	remaining: 5m 6s
# 178:	learn: 0.5820474	total: 1m 6s	remaining: 5m 5s
# 179:	learn: 0.5818479	total: 1m 7s	remaining: 5m 6s
# 180:	learn: 0.5817022	total: 1m 7s	remaining: 5m 6s
# 181:	learn: 0.5815567	total: 1m 8s	remaining: 5m 5s
# 182:	learn: 0.5814910	total: 1m 8s	remaining: 5m 5s
# 183:	learn: 0.5813649	total: 1m 8s	remaining: 5m 4s
# 184:	learn: 0.5812914	total: 1m 9s	remaining: 5m 4s
# 185:	learn: 0.5811617	total: 1m 9s	remaining: 5m 3s
# 186:	learn: 0.5810500	total: 1m 9s	remaining: 5m 3s
# 187:	learn: 0.5809950	total: 1m 9s	remaining: 5m 2s
# 188:	learn: 0.5809360	total: 1m 10s	remaining: 5m 1s
# 189:	learn: 0.5807627	total: 1m 10s	remaining: 5m 1s
# 190:	learn: 0.5806733	total: 1m 11s	remaining: 5m 1s
# 191:	learn: 0.5805755	total: 1m 11s	remaining: 5m
# 192:	learn: 0.5804778	total: 1m 11s	remaining: 5m
# 193:	learn: 0.5802770	total: 1m 12s	remaining: 4m 59s
# 194:	learn: 0.5801011	total: 1m 12s	remaining: 4m 59s
# 195:	learn: 0.5799915	total: 1m 12s	remaining: 4m 59s
# 196:	learn: 0.5798919	total: 1m 13s	remaining: 4m 58s
# 197:	learn: 0.5797865	total: 1m 13s	remaining: 4m 57s
# 198:	learn: 0.5796609	total: 1m 13s	remaining: 4m 57s
# 199:	learn: 0.5795236	total: 1m 14s	remaining: 4m 56s
# 200:	learn: 0.5794458	total: 1m 14s	remaining: 4m 55s
# 201:	learn: 0.5793280	total: 1m 14s	remaining: 4m 55s
# 861:	learn: 0.5438298	total: 5m 6s	remaining: 49.1s
# 862:	learn: 0.5438022	total: 5m 6s	remaining: 48.7s
# 863:	learn: 0.5437607	total: 5m 7s	remaining: 48.4s
# 864:	learn: 0.5437387	total: 5m 7s	remaining: 48s
# 865:	learn: 0.5436914	total: 5m 7s	remaining: 47.6s
# 866:	learn: 0.5436579	total: 5m 8s	remaining: 47.3s
# 867:	learn: 0.5436373	total: 5m 8s	remaining: 47s
# 868:	learn: 0.5436108	total: 5m 9s	remaining: 46.6s
# 869:	learn: 0.5435862	total: 5m 9s	remaining: 46.2s
# 870:	learn: 0.5435604	total: 5m 9s	remaining: 45.9s
# 871:	learn: 0.5435249	total: 5m 10s	remaining: 45.5s
# 872:	learn: 0.5434885	total: 5m 10s	remaining: 45.2s
# 873:	learn: 0.5434506	total: 5m 10s	remaining: 44.8s
# 874:	learn: 0.5434169	total: 5m 11s	remaining: 44.5s
# 875:	learn: 0.5433933	total: 5m 11s	remaining: 44.1s
# 876:	learn: 0.5433635	total: 5m 11s	remaining: 43.7s
# 877:	learn: 0.5433507	total: 5m 12s	remaining: 43.4s
# 878:	learn: 0.5433200	total: 5m 12s	remaining: 43s
# 879:	learn: 0.5432918	total: 5m 12s	remaining: 42.6s
# 880:	learn: 0.5432651	total: 5m 13s	remaining: 42.3s
# 881:	learn: 0.5432262	total: 5m 13s	remaining: 41.9s
# 882:	learn: 0.5431777	total: 5m 13s	remaining: 41.6s
# 883:	learn: 0.5431429	total: 5m 13s	remaining: 41.2s
# 884:	learn: 0.5431145	total: 5m 14s	remaining: 40.8s
# 885:	learn: 0.5430864	total: 5m 14s	remaining: 40.5s
# 886:	learn: 0.5430681	total: 5m 14s	remaining: 40.1s
# 887:	learn: 0.5430319	total: 5m 15s	remaining: 39.8s
# 888:	learn: 0.5430078	total: 5m 15s	remaining: 39.4s
# 889:	learn: 0.5429923	total: 5m 15s	remaining: 39s
# 890:	learn: 0.5429527	total: 5m 16s	remaining: 38.7s
# 891:	learn: 0.5429175	total: 5m 16s	remaining: 38.3s
# 892:	learn: 0.5428806	total: 5m 16s	remaining: 38s
# 893:	learn: 0.5428578	total: 5m 17s	remaining: 37.6s
# 894:	learn: 0.5428208	total: 5m 17s	remaining: 37.3s
# 895:	learn: 0.5427855	total: 5m 18s	remaining: 36.9s
# 896:	learn: 0.5427560	total: 5m 18s	remaining: 36.6s
# 897:	learn: 0.5427194	total: 5m 18s	remaining: 36.2s
# 898:	learn: 0.5427031	total: 5m 19s	remaining: 35.9s
# 899:	learn: 0.5426813	total: 5m 19s	remaining: 35.5s
# 900:	learn: 0.5426616	total: 5m 19s	remaining: 35.1s
# 901:	learn: 0.5426133	total: 5m 20s	remaining: 34.8s
# 902:	learn: 0.5425806	total: 5m 20s	remaining: 34.4s
# 903:	learn: 0.5425639	total: 5m 20s	remaining: 34.1s
# 904:	learn: 0.5425358	total: 5m 21s	remaining: 33.7s
# 905:	learn: 0.5424999	total: 5m 21s	remaining: 33.4s
# 906:	learn: 0.5424735	total: 5m 21s	remaining: 33s
# 907:	learn: 0.5424436	total: 5m 22s	remaining: 32.6s
# 908:	learn: 0.5424116	total: 5m 22s	remaining: 32.3s
# 909:	learn: 0.5423808	total: 5m 22s	remaining: 31.9s
# 910:	learn: 0.5423334	total: 5m 23s	remaining: 31.6s
# 911:	learn: 0.5422881	total: 5m 23s	remaining: 31.2s
# 912:	learn: 0.5422609	total: 5m 24s	remaining: 30.9s
# 913:	learn: 0.5422061	total: 5m 24s	remaining: 30.5s
# 914:	learn: 0.5421697	total: 5m 24s	remaining: 30.2s
# 915:	learn: 0.5421402	total: 5m 25s	remaining: 29.8s
# 916:	learn: 0.5420990	total: 5m 25s	remaining: 29.5s
# 917:	learn: 0.5420808	total: 5m 25s	remaining: 29.1s
# 918:	learn: 0.5420481	total: 5m 26s	remaining: 28.7s
# 919:	learn: 0.5420285	total: 5m 26s	remaining: 28.4s
# 920:	learn: 0.5419906	total: 5m 27s	remaining: 28.1s
# 921:	learn: 0.5419615	total: 5m 27s	remaining: 27.7s
# 922:	learn: 0.5419245	total: 5m 27s	remaining: 27.4s
# 923:	learn: 0.5418989	total: 5m 28s	remaining: 27s
# 924:	learn: 0.5418610	total: 5m 28s	remaining: 26.6s
# 925:	learn: 0.5418378	total: 5m 28s	remaining: 26.3s
# 926:	learn: 0.5418002	total: 5m 29s	remaining: 25.9s
# 927:	learn: 0.5417650	total: 5m 29s	remaining: 25.6s
# 928:	learn: 0.5417225	total: 5m 29s	remaining: 25.2s
# 929:	learn: 0.5417075	total: 5m 29s	remaining: 24.8s
# 930:	learn: 0.5416742	total: 5m 30s	remaining: 24.5s
# 931:	learn: 0.5416504	total: 5m 30s	remaining: 24.1s
# 932:	learn: 0.5416227	total: 5m 30s	remaining: 23.8s
# 933:	learn: 0.5415949	total: 5m 31s	remaining: 23.4s
# 934:	learn: 0.5415747	total: 5m 31s	remaining: 23.1s
# 935:	learn: 0.5415555	total: 5m 31s	remaining: 22.7s
# 936:	learn: 0.5415167	total: 5m 32s	remaining: 22.3s
# 937:	learn: 0.5414942	total: 5m 32s	remaining: 22s
# 938:	learn: 0.5414690	total: 5m 33s	remaining: 21.6s
# 939:	learn: 0.5414478	total: 5m 33s	remaining: 21.3s
# 940:	learn: 0.5414033	total: 5m 33s	remaining: 20.9s
# 941:	learn: 0.5413526	total: 5m 34s	remaining: 20.6s
# 942:	learn: 0.5413239	total: 5m 34s	remaining: 20.2s
# 943:	learn: 0.5413061	total: 5m 34s	remaining: 19.9s
# 944:	learn: 0.5412604	total: 5m 35s	remaining: 19.5s
# 945:	learn: 0.5412325	total: 5m 35s	remaining: 19.1s
# 946:	learn: 0.5412046	total: 5m 35s	remaining: 18.8s
# 947:	learn: 0.5411784	total: 5m 36s	remaining: 18.4s
# 948:	learn: 0.5411536	total: 5m 36s	remaining: 18.1s
# 949:	learn: 0.5411290	total: 5m 36s	remaining: 17.7s
# 950:	learn: 0.5410974	total: 5m 37s	remaining: 17.4s
# 951:	learn: 0.5410696	total: 5m 37s	remaining: 17s
# 952:	learn: 0.5410388	total: 5m 38s	remaining: 16.7s
# 953:	learn: 0.5410136	total: 5m 38s	remaining: 16.3s
# 954:	learn: 0.5409967	total: 5m 38s	remaining: 16s
# 955:	learn: 0.5409698	total: 5m 39s	remaining: 15.6s
# 956:	learn: 0.5409333	total: 5m 39s	remaining: 15.3s
# 957:	learn: 0.5408994	total: 5m 40s	remaining: 14.9s
# 958:	learn: 0.5408591	total: 5m 40s	remaining: 14.6s
# 959:	learn: 0.5408011	total: 5m 40s	remaining: 14.2s
# 960:	learn: 0.5407792	total: 5m 41s	remaining: 13.8s
# 961:	learn: 0.5407580	total: 5m 41s	remaining: 13.5s
# 962:	learn: 0.5407286	total: 5m 41s	remaining: 13.1s
# 963:	learn: 0.5406768	total: 5m 42s	remaining: 12.8s
# 964:	learn: 0.5406555	total: 5m 42s	remaining: 12.4s
# 965:	learn: 0.5406207	total: 5m 42s	remaining: 12.1s
# 966:	learn: 0.5405983	total: 5m 42s	remaining: 11.7s
# 967:	learn: 0.5405709	total: 5m 43s	remaining: 11.3s
# 968:	learn: 0.5405362	total: 5m 43s	remaining: 11s
# 969:	learn: 0.5405175	total: 5m 43s	remaining: 10.6s
# 970:	learn: 0.5404930	total: 5m 44s	remaining: 10.3s
# 971:	learn: 0.5404637	total: 5m 44s	remaining: 9.93s
# 972:	learn: 0.5404288	total: 5m 44s	remaining: 9.57s
# 973:	learn: 0.5403947	total: 5m 45s	remaining: 9.22s
# 974:	learn: 0.5403656	total: 5m 45s	remaining: 8.86s
# 975:	learn: 0.5403415	total: 5m 45s	remaining: 8.51s
# 976:	learn: 0.5402859	total: 5m 46s	remaining: 8.15s
# 977:	learn: 0.5402555	total: 5m 46s	remaining: 7.8s
# 978:	learn: 0.5402360	total: 5m 47s	remaining: 7.45s
# 979:	learn: 0.5402016	total: 5m 47s	remaining: 7.09s
# 980:	learn: 0.5401775	total: 5m 47s	remaining: 6.74s
# 981:	learn: 0.5401494	total: 5m 48s	remaining: 6.38s
# 982:	learn: 0.5401242	total: 5m 48s	remaining: 6.03s
# 983:	learn: 0.5400942	total: 5m 48s	remaining: 5.67s
# 984:	learn: 0.5400593	total: 5m 49s	remaining: 5.32s
# 985:	learn: 0.5400122	total: 5m 49s	remaining: 4.96s
# 986:	learn: 0.5399612	total: 5m 50s	remaining: 4.61s
# 987:	learn: 0.5399321	total: 5m 50s	remaining: 4.25s
# 988:	learn: 0.5399191	total: 5m 50s	remaining: 3.9s
# 989:	learn: 0.5399041	total: 5m 51s	remaining: 3.54s
# 990:	learn: 0.5398612	total: 5m 51s	remaining: 3.19s
# 991:	learn: 0.5398364	total: 5m 51s	remaining: 2.84s
# 992:	learn: 0.5398039	total: 5m 52s	remaining: 2.48s
# 993:	learn: 0.5397854	total: 5m 52s	remaining: 2.13s
# 994:	learn: 0.5397709	total: 5m 52s	remaining: 1.77s
# 995:	learn: 0.5397416	total: 5m 53s	remaining: 1.42s
# 996:	learn: 0.5396999	total: 5m 53s	remaining: 1.06s
# 997:	learn: 0.5396814	total: 5m 53s	remaining: 709ms
# 998:	learn: 0.5396539	total: 5m 54s	remaining: 354ms
# 999:	learn: 0.5396230	total: 5m 54s	remaining: 0us
# F1 score: 0.4355629384957701

# %% [markdown]
# Hyperparameter Tuning:

# %%
# Define the parameter grid for tuning
param_grid = {
    'iterations': [200, 500, 700],
    'learning_rate': [0.01, 0.05, 0.1],
    'depth': [4, 6, 8],
    'l2_leaf_reg': [1, 3, 5],
}

# Initialize the CatBoostClassifier with multi-class settings
cat = CatBoostClassifier(loss_function='MultiClass', random_state=42, verbose=0)

# Perform grid search using CatBoost's built-in function
grid_search_result = cat.grid_search(
    param_grid,
    X=X_train_final,
    y=y_train_encoded,
    cv=5,  # 5-fold cross-validation
    stratified=True,
    refit=True  # Automatically refits the model with the best parameters
)
# Out:
# bestTest = 0.7563937615
# bestIteration = 199
#
# 0:	loss: 0.7563938	best: 0.7563938 (0)	total: 1m 1s	remaining: 1h 21m 45s
#
# bestTest = 0.6237870575
# bestIteration = 199
#
# 1:	loss: 0.6237871	best: 0.6237871 (1)	total: 2m 4s	remaining: 1h 22m 9s
#
# bestTest = 0.6026429291
# bestIteration = 199
#
# 2:	loss: 0.6026429	best: 0.6026429 (2)	total: 3m 4s	remaining: 1h 19m 56s
#
# bestTest = 0.7566054602
# bestIteration = 199
#
# 3:	loss: 0.7566055	best: 0.6026429 (2)	total: 4m 11s	remaining: 1h 20m 43s
#
# bestTest = 0.624018946
# bestIteration = 199
#
# 4:	loss: 0.6240189	best: 0.6026429 (2)	total: 5m 20s	remaining: 1h 21m 12s
#
# bestTest = 0.6030868595
# bestIteration = 199
#
# 5:	loss: 0.6030869	best: 0.6026429 (2)	total: 6m 17s	remaining: 1h 18m 35s
#
# bestTest = 0.7567858133
# bestIteration = 199
#
# 6:	loss: 0.7567858	best: 0.6026429 (2)	total: 7m 17s	remaining: 1h 17m
#
# bestTest = 0.6240708388
# bestIteration = 199
#
# 7:	loss: 0.6240708	best: 0.6026429 (2)	total: 8m 14s	remaining: 1h 15m 16s
#
# bestTest = 0.6027372402
# bestIteration = 199
#
# 8:	loss: 0.6027372	best: 0.6026429 (2)	total: 9m 13s	remaining: 1h 13m 51s
#
# bestTest = 0.653281706
# bestIteration = 499
#
# 9:	loss: 0.6532817	best: 0.6026429 (2)	total: 11m 46s	remaining: 1h 23m 32s
#
# bestTest = 0.5974467913
# bestIteration = 499
#
# 10:	loss: 0.5974468	best: 0.5974468 (10)	total: 14m 2s	remaining: 1h 29m 22s
#
# bestTest = 0.5849429573
# bestIteration = 499
#
# 11:	loss: 0.5849430	best: 0.5849430 (11)	total: 16m 23s	remaining: 1h 34m 13s
#
# bestTest = 0.653545784
# bestIteration = 499
#
# 12:	loss: 0.6535458	best: 0.5849430 (11)	total: 18m 53s	remaining: 1h 38m 47s
#
# bestTest = 0.5983364858
# bestIteration = 499
#
# 13:	loss: 0.5983365	best: 0.5849430 (11)	total: 21m 9s	remaining: 1h 41m 16s
#
# bestTest = 0.5857346224
# bestIteration = 499
#
# 14:	loss: 0.5857346	best: 0.5849430 (11)	total: 23m 14s	remaining: 1h 42m 14s
#
# bestTest = 0.6538324455
# bestIteration = 499
#
# 15:	loss: 0.6538324	best: 0.5849430 (11)	total: 25m 27s	remaining: 1h 43m 23s
#
# bestTest = 0.5982121709
# bestIteration = 499
#
# 16:	loss: 0.5982122	best: 0.5849430 (11)	total: 27m 34s	remaining: 1h 43m 47s
#
# bestTest = 0.5857103375
# bestIteration = 499
#
# 17:	loss: 0.5857103	best: 0.5849430 (11)	total: 29m 38s	remaining: 1h 43m 44s
#
# bestTest = 0.6370371682
# bestIteration = 699
#
# 18:	loss: 0.6370372	best: 0.5849430 (11)	total: 32m 40s	remaining: 1h 46m 37s
#
# bestTest = 0.5907322885
# bestIteration = 699
#
# 19:	loss: 0.5907323	best: 0.5849430 (11)	total: 35m 37s	remaining: 1h 48m 39s
#
# bestTest = 0.5806344761
# bestIteration = 699
#
# 20:	loss: 0.5806345	best: 0.5806345 (20)	total: 38m 29s	remaining: 1h 49m 59s
#
# bestTest = 0.637511461
# bestIteration = 699
#
# 21:	loss: 0.6375115	best: 0.5806345 (20)	total: 41m 30s	remaining: 1h 51m 18s
#
# bestTest = 0.591359873
# bestIteration = 699
#
# 22:	loss: 0.5913599	best: 0.5806345 (20)	total: 44m 26s	remaining: 1h 52m 4s
#
# bestTest = 0.5811153391
# bestIteration = 699
#
# 23:	loss: 0.5811153	best: 0.5806345 (20)	total: 47m 23s	remaining: 1h 52m 33s
#
# bestTest = 0.6377718552
# bestIteration = 699
#
# 24:	loss: 0.6377719	best: 0.5806345 (20)	total: 50m 28s	remaining: 1h 53m 4s
#
# bestTest = 0.5914779847
# bestIteration = 699
#
# 25:	loss: 0.5914780	best: 0.5806345 (20)	total: 53m 26s	remaining: 1h 53m 2s
#
# bestTest = 0.58163637
# bestIteration = 699
#
# 26:	loss: 0.5816364	best: 0.5806345 (20)	total: 56m 29s	remaining: 1h 52m 58s
#
# bestTest = 0.7342355183
# bestIteration = 199
#
# 27:	loss: 0.7342355	best: 0.5806345 (20)	total: 57m 46s	remaining: 1h 49m 21s
#
# bestTest = 0.60368162
# bestIteration = 199
#
# 28:	loss: 0.6036816	best: 0.5806345 (20)	total: 58m 50s	remaining: 1h 45m 30s
#
# bestTest = 0.5864622046
# bestIteration = 199
#
# 29:	loss: 0.5864622	best: 0.5806345 (20)	total: 59m 53s	remaining: 1h 41m 48s
#
# bestTest = 0.7349064355
# bestIteration = 199
#
# 30:	loss: 0.7349064	best: 0.5806345 (20)	total: 1h 57s	remaining: 1h 38m 19s
#
# bestTest = 0.6042523255
# bestIteration = 199
#
# 31:	loss: 0.6042523	best: 0.5806345 (20)	total: 1h 1m 57s	remaining: 1h 34m 52s
#
# bestTest = 0.5877852564
# bestIteration = 199
#
# 32:	loss: 0.5877853	best: 0.5806345 (20)	total: 1h 2m 57s	remaining: 1h 31m 35s
#
# bestTest = 0.7352547772
# bestIteration = 199
#
# 33:	loss: 0.7352548	best: 0.5806345 (20)	total: 1h 3m 59s	remaining: 1h 28m 28s
#
# bestTest = 0.6047399314
# bestIteration = 199
#
# 34:	loss: 0.6047399	best: 0.5806345 (20)	total: 1h 4m 58s	remaining: 1h 25m 24s
#
# bestTest = 0.5883358767
# bestIteration = 199
#
# 35:	loss: 0.5883359	best: 0.5806345 (20)	total: 1h 5m 54s	remaining: 1h 22m 22s
#
# bestTest = 0.6298710352
# bestIteration = 499
#
# 36:	loss: 0.6298710	best: 0.5806345 (20)	total: 1h 8m 25s	remaining: 1h 21m 21s
#
# bestTest = 0.5825693365
# bestIteration = 499
#
# 37:	loss: 0.5825693	best: 0.5806345 (20)	total: 1h 10m 57s	remaining: 1h 20m 18s
#
# bestTest = 0.5746933087
# bestIteration = 499
#
# 38:	loss: 0.5746933	best: 0.5746933 (38)	total: 1h 13m 45s	remaining: 1h 19m 25s
#
# bestTest = 0.6304641994
# bestIteration = 499
#
# 39:	loss: 0.6304642	best: 0.5746933 (38)	total: 1h 17m 24s	remaining: 1h 19m 21s
#
# bestTest = 0.5832052335
# bestIteration = 499
#
# 40:	loss: 0.5832052	best: 0.5746933 (38)	total: 1h 21m 17s	remaining: 1h 19m 18s
#
# bestTest = 0.575407468
# bestIteration = 499
#
# 41:	loss: 0.5754075	best: 0.5746933 (38)	total: 1h 24m 9s	remaining: 1h 18m 8s
#
# bestTest = 0.6309154602
# bestIteration = 499
#
# 42:	loss: 0.6309155	best: 0.5746933 (38)	total: 1h 27m 7s	remaining: 1h 16m 59s
#
# bestTest = 0.5835469494
# bestIteration = 499
#
# 43:	loss: 0.5835469	best: 0.5746933 (38)	total: 1h 29m 52s	remaining: 1h 15m 34s
#
# bestTest = 0.5759232971
# bestIteration = 499
#
# 44:	loss: 0.5759233	best: 0.5746933 (38)	total: 1h 32m 40s	remaining: 1h 14m 8s
#
# bestTest = 0.6151330069
# bestIteration = 699
#
# 45:	loss: 0.6151330	best: 0.5746933 (38)	total: 1h 36m 31s	remaining: 1h 13m 26s
#
# bestTest = 0.5779102948
# bestIteration = 699
#
# 46:	loss: 0.5779103	best: 0.5746933 (38)	total: 1h 39m 57s	remaining: 1h 12m 18s
#
# bestTest = 0.5722138949
# bestIteration = 699
#
# 47:	loss: 0.5722139	best: 0.5722139 (47)	total: 1h 43m 20s	remaining: 1h 11m 2s

# %%
best_cat = cat

# %% [markdown]
# Submission on Kaggle:

# %%
y_pred_cat = cat.predict(test_final).flatten()

label_mapping = {
    0: "1. CANCELLED",
    1: "2. NON-COMP",
    2: "3. MED ONLY",
    3: "4. TEMPORARY",
    4: "5. PPD SCH LOSS",
    5: "6. PPD NSL",
    6: "7. PTD",
    7: "8. DEATH"
}

y_pred_test_mapped_cat = pd.Series(y_pred_cat).map(label_mapping)

submission = pd.DataFrame({
    "Claim Identifier": test["Claim Identifier"],  # Use the 1-dimensional Claim Identifier
    "Claim Injury Type": y_pred_test_mapped_cat  # Use the mapped, 1-dimensional predictions
})

# Step 5: Save the submission DataFrame to a CSV file
submission.to_csv("Group26_Version06.csv", index=False)

# Optional: Display the first few rows of the submission to verify
submission.head()
